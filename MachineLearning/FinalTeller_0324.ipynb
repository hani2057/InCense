# %% [markdown]
# # ** 0. Environment **

# %%
from google.colab import drive, files
# drive.mount('/content/drive')
# file_path = '/content/drive/MyDrive'

from collections import deque
import re

import pandas as pd
import os

import numpy as np

# %% [markdown]
# # ** 1. Data Set **

# %%
## Function :: Convert text 2 list
def Category_binder(perfume, col_num):

    ## 01. 대카테고리 분류
    category = []
    if '"' not in perfume[col_num]:
        category.append(perfume[col_num])
        perfume[col_num] = category
    else:
        category.append(perfume[col_num].replace('"','').strip())
        while True:
            a_item = perfume.pop(col_num + 1)
            if '"' not in a_item:

                category.append(a_item.strip())
            else:
                category.append(a_item.replace('"','').strip())
                break
        perfume[col_num] = category


    ## 02. 카테고리 내부 단어 전처리
    new = set()
    qq = deque(perfume[col_num])
    while qq:
        item = qq.popleft().lower()
        item = item.replace('-', '').strip()
        item = item.replace('(', '').strip()
        item = item.replace(')', '').strip()
        if 'and' in item or 'with' in item or 'of' in item:
            not_and, is_and = [], False
            temp = list(item.split())
            for j in range(len(temp)):
                if temp[j] == 'and':
                    is_and = True
                    continue
                elif temp[j] == 'with':
                    is_and = True
                    continue
                elif temp[j] == 'of':
                    is_and = True
                    continue
                not_and.append(temp[j])
            if is_and:
                for k in range(len(not_and)):
                    new.add(not_and[k])
            else:
                new.add(item)
        else:
            new.add(item)
    perfume[col_num] = new
    return perfume

## Function :: Convert list 2 txt
def TextMaker(name, catego):
    text = ''
    for tt in sorted(list(catego)):
        text += str(tt)
        text += ','
    with open(name + '.txt', 'w') as f:
        f.write(text[:-2])

# %%
for perfume in sorted(perfumes, key=lambda x: int(x[0])):
    print(perfume)
# Out:
# ['0', 'PACO RABANNE', '1 Million Lucky', 395.0, 244.55, 100.0, 'EDT', 'Men', {'woody'}, {'patchouli', 'vetiver', 'oakmoss'}, {'jasmine', 'cashmir wood', 'cedar', 'honey', 'hazelnut'}, 5.0, 'noon', '4.2', '98.1K']
# ['1', 'Roberto Cavalli', 'Paradiso Assoluto', 415.0, 107.95, 50.0, 'EDP', 'Women', {'floral'}, {'patchouli', 'sandalwood', 'vanilla'}, {'lily', 'wild', 'jasmine', 'red'}, 4.8, 'noon', '4.2', '98.1K']
# ['2', 'S.T.Dupont', 'Royal Amber', 265.0, 186.9, 100.0, 'EDP', 'Unisex', {'arabian'}, {'mint', 'wood moss', 'lemon'}, {'cedar', 'sandalwood'}, 5.0, 'noon', '4.2', '98.1K']
# ['3', 'GUESS', 'Seductive Blue', 290.0, 103.2, 100.0, 'EDT', 'Men', {'spicy'}, {'moss', 'cashmere wood', 'rippled sand accord'}, {'blue', 'accord', 'aquaspace', 'geranium', 'coral'}, 3.0, 'noon', '4.2', '98.1K']
# ['4', 'Roberto Cavalli', 'Uomo', 260.0, 94.95, 50.0, 'EDP', 'Women', {'arabian'}, {'benzoin', 'tonka bean', 'vanille'}, {'african orange flower'}, 4.8, 'noon', '4.2', '98.1K']
# ['5', 'Roberto Cavalli', 'cavalli', 260.0, 94.95, 50.0, 'EDP', 'Women', {'arabian'}, {'benzoin', 'tonka bean', 'vanille'}, {'african orange flower'}, 4.8, 'noon', '4.2', '98.1K']
# ['6', 'HUGO BOSS', 'The Scent', 220.0, 220.0, 50.0, 'EDP', 'Women', {'oriental'}, {'roasted cocoa'}, {'lavender', 'osmanthus flower'}, 4.0, 'rich&light', '43', '4K']
# ['7', 'DORALL COLLECTION', 'Gold Secret', 43.0, 12.35, 100.0, 'EDT', 'Men', {'fruity'}, {'labdanum', 'musk'}, {'lavender', 'cloves'}, 2.9, 'B.A.G', '3.7', '14.1K']
# ['8', 'GUCCI', 'Bamboo', 575.0, 189.0, 75.0, 'EDP', 'Women', {'floral'}, {'sandalwood'}, {'casablanca', 'ylang', 'lily', 'extracomoros'}, 4.8, 'Al-Najm', '3.7', '347']
# ['9', 'Yves Saint Laurent', 'M7 Oud Absolu', 536.0, 273.0, 80.0, 'EDT', 'Men', {'arabian'}, {'cistus', 'myrrh', 'oud', 'amber'}, {'patchouli'}, 4.5, 'Al-Najm', '3.7', '347']
# ['10', 'CERRUTI 1881', '1881', 335.0, 119.55, 100.0, 'EDT', 'Men', {'fresh'}, {'pepper', 'pine', 'oak moss', 'cedar', 'sandalwood', 'musk', 'patchouli', 'tree'}, {'rose', 'vetiver', 'ylangylang', 'cassia', 'lilyofthevalley'}, 4.3, 'AMLAQ', '3.9', '135']
# ['11', 'Calvin Klein', 'IN 2 U MEN', 152.0, 85.0, 100.0, 'EDT', 'Men', {'citrus'}, {'vetiver', 'cedar', 'white musk'}, {'cacao pod'}, 3.7, 'AMLAQ', '3.9', '135']
# ['12', 'Rasasi', 'Royale Blue', 97.0, 45.3, 75.0, 'EDP', 'Men', {'fruity'}, {'delicate musky sensual woods'}, {'distinct', 'exotic'}, 4.5, 'Bismat Eatar', '3.9', '66']
# ['13', 'MONTALE', 'Black Oud', 455.0, 240.0, 100.0, 'EDP', 'Men', {'floral'}, {'agarwood', 'mandarin orange'}, {'patchouli', 'musk'}, 3.3, 'noon', '4.2', '98.1K']
# ['14', 'Yves Saint Laurent', "L'Homme", 536.0, 273.8, 100.0, 'EDT', 'Men', {'woody'}, {'cedar', 'tahitian vetiver', 'tonka bean'}, {'white pepper', 'violet leaf', 'basil', 'spices'}, 3.0, 'noon', '4.2', '98.1K']
# ['15', 'CHLOE', 'Love Story', 483.0, 274.95, 75.0, 'EDP', 'Women', {'floral'}, {'cedar', 'patchouli', 'musk', 'cashmirwood'}, {'peach', 'rose', 'black currant', 'orange blossom', 'stephanotis'}, 5.0, 'noon', '4.2', '98.1K']
# ['16', 'NARCISO RODRIGUEZ', 'Narciso Rouge', 591.0, 275.15, 90.0, 'EDP', 'Women', {'woody'}, {'vetiver', 'tonka beans', 'cedar wood'}, {'musk'}, 4.5, 'noon', '4.2', '98.1K']
# ['17', 'DORALL COLLECTION', '24 Pure', 22.0, 9.85, 100.0, 'EDT', 'Men', {'fresh'}, {'amber', 'coumarin', 'sandalwood', 'vanilla', 'musk'}, {'cinnamon', 'nutmeg', 'pink pepper', 'lily', 'red fruits', 'cumin', 'jasmin', 'cardomon'}, 4.9, 'B.A.G', '3.7', '14.1K']
# ['18', 'Rasasi', 'Romance', 60.0, 35.25, 45.0, 'EDP', 'Women', {'floral'}, {'amber', 'cedar', 'sandalwood', 'musk', 'powdery notes'}, {'rose', 'jasmine'}, 4.5, 'B.A.G', '3.7', '14.1K']
# ['19', 'BOUCHERON', 'Quatre', 327.0, 171.5, 100.0, 'EDP', 'Women', {'floral'}, {'golden woods musk'}, {'sambac jasmine absolute', 'rose absolute'}, 5.0, 'Star.perfume', '3.9', '537']
# ['20', 'NARCISO RODRIGUEZ', 'Narciso Rodriguez', 595.0, 200.0, 100.0, 'EDP', 'Women', {'floral'}, {'patchouli', 'sandalwood'}, {'amber', 'musk'}, 4.6, 'hadayiq baris', '3.8', '122']
# ['21', 'Alina Corel', 'Monsieur Intense Gold', 31.45, 31.45, 100.0, 'EDP', 'Unisex', {'woody'}, {'rare wood', 'white musk', 'amber fat'}, {'gaiak wood', 'shepherd', 'teak wood', 'saffron'}, 5.0, 'Kathya', '3.8', '116']
# ['22', 'Revlon', 'Charlie Gold', 143.0, 43.0, 100.0, 'EDT', 'Women', {'woody'}, {'woody accords', 'sandalwood', 'vanilla', 'cedar wood', 'caramel musk'}, {'cinnamon', 'rose', 'jasmine', 'muget', 'freesia'}, 4.0, 'Golden Perfumesعطر أص?? 100  %', '3.6', '113']
# ['23', 'TED LAPIDUS', 'Pour Homme', 129.0, 44.45, 100.0, 'EDT', 'Men', {'woody'}, {'tobacco', 'amber', 'cedar', 'sandalwood', 'musk', 'patchouli', 'tonka bean', 'oakmoss'}, {'pine tree', 'incense', 'rose', 'jasmine', 'brazilian rosewood', 'honey', 'orris root', 'petitgrain', 'lilyofthevalley', 'caraway'}, 5.0, 'neo lek', '3.5', '88']
# ['24', 'Britney Spears', 'Fantasy', 170.0, 90.0, 100.0, 'EDP', 'Women', {'vanilla'}, {'luid sandalwood', 'amber', 'jasmine', 'vanilla'}, {'verbena', 'grapefruit blossom', 'sweet napolitano cake', 'jacaranda wood'}, 5.0, 'Cute Shop', '3.8', '76']
# ['25', 'GUCCI', 'Bloom Aqua Di Fiori', 515.0, 311.8, 100.0, 'EDT', 'Women', {'fruity'}, {'jasmine'}, {'tuberose'}, 4.7, 'noon', '4.2', '98.1K']
# ['26', 'Yves Saint Laurent', 'Body Kouros', 510.0, 203.6, 100.0, 'EDT', 'Men', {'woody'}, {'benzoin'}, {'chinese cedar', 'clary sage'}, 5.0, 'noon', '4.2', '98.1K']
# ['27', 'Van Cleef & Arpels', 'First', 170.95, 170.95, 100.0, 'EDT', 'Women', {'floral'}, {'amber', 'civet', 'honey', 'vetiver', 'sandalwood', 'vanilla', 'musk', 'tonka bean', 'oakmoss'}, {'narcissus', 'turkish rose', 'jasmine', 'carnation', 'orchid', 'ylangylang', 'tuberose', 'hiacynth', 'lilyofthevalley', 'orris root'}, 5.0, 'noon', '4.2', '98.1K']
# ['28', 'NARCISO RODRIGUEZ', 'Narciso Rodriguez', 465.0, 226.0, 100.0, 'EDP', 'Women', {'musk'}, {'patchouli', 'sandalwood'}, {'amber', 'musk'}, 4.0, 'Brand Land', '4.2', '98']
# ['29', 'S.T.Dupont', 'S.T. Dupont', 120.0, 79.35, 100.0, 'EDT', 'Men', {'spicy'}, {'amber', 'sandalwood', 'musk', 'patchouli', 'coconut'}, {'cinnamon', 'iris', 'cypress', 'carnation', 'jasmine', 'lavender'}, 5.0, 'noon', '4.2', '98.1K']
# ['30', 'Estee Lauder', 'Knowing', 585.0, 220.0, 75.0, 'EDP', 'Women', {'woody'}, {'vetiver', 'sandalwood', 'amber', 'oakmoss'}, {'patchouli', 'flower', 'jasmine', 'orange'}, 5.0, 'KAYA', '4.3', '4K']
# ['31', 'Geoffrey Beene', 'Grey Flannel For Men', 361.0, 79.0, 120.0, 'EDT', 'Men', {'woody'}, {'almond', 'vetiver', 'cedar', 'tonka bean', 'oakmoss'}, {'narcissus', 'iris', 'mimose', 'rose', 'sage', 'violet', 'geranium'}, 5.0, 'top langri', '3.7', '347']
# ['32', 'Dolce & Gabbana', 'The Only One', 596.0, 187.3, 100.0, 'EDP', 'Women', {'oriental'}, {'marshmallow', 'sandalwood', 'vanilla', 'heliotrope'}, {'coffee', 'iris'}, 5.0, 'Asrar Aljamal', '3.5', '244']
# ['33', 'Rasasi', 'Al Wisam Day', 177.0, 76.0, 100.0, 'EDP', 'Men', {'oriental'}, {'rich', 'musty', 'oud', 'oak moss'}, {'milky', 'cedarwood', 'amber nuanced clary sage', 'sandalwood', 'soft', 'woody'}, 4.3, 'hadayiq baris', '3.8', '122']
# ['34', 'Mancera', 'Black Vanilla', 588.0, 296.0, 120.0, 'EDP', 'Unisex', {'woody'}, {'madagascar', 'white', 'vanilla', 'musk', 'from', 'pods'}, {'jasmine', 'violet', 'delicate bulgarian rose'}, 3.0, 'MAKE UP', '3.8', '71']
# ['35', 'Dior', 'Addict', 715.0, 333.8, 100.0, 'EDP', 'Women', {'floral'}, {'bean', 'wood', 'bourbon vanilla', 'tonka', 'sandal'}, {'orange', 'night queen flower', 'rose', 'flower', 'bulgarian'}, 4.5, 'Parfume-Stor', '3.5', '63']
# ['36', 'S.T.Dupont', 'Passenger', 182.0, 108.9, 100.0, 'EDT', 'Men', {'spicy'}, {'guaiac wood', 'benzoin'}, {'pink pepper', 'cardamom', 'ginger', 'lavender'}, 5.0, 'perfumes--addresses', '4.4', '59']
# ['37', 'BURBERRY', 'Brit Rhythm Intense', 370.0, 136.65, 90.0, 'EDT', 'Men', {'spicy'}, {'guaiac wood', 'tonka beans', 'cashmere wood', 'coumarin', 'sandalwood', 'vanilla', 'leather'}, {'amber', 'lavender', 'mint', 'patchouli', 'basil'}, 4.6, 'noon', '4.2', '98.1K']
# ['38', 'Calvin Klein', 'CK Be', 247.0, 108.3, 200.0, 'EDT', 'Men', {'floral'}, {'amber', 'cedar', 'sandalwood', 'vanilla', 'musk', 'opoponax'}, {'peach', 'green grass', 'jasmine', 'orchid', 'magnolia', 'freesia'}, 5.0, 'noon', '4.2', '98.1K']
# ['39', 'GUCCI', 'Guilty', 504.0, 214.9, 75.0, 'EDT', 'Women', {'floral'}, {'patchouli', 'amber'}, {'raspberry vilolet', 'peach', 'lilac'}, 5.0, 'noon', '4.2', '98.1K']
# ['40', 'AIGNER', 'Starlight', 341.0, 126.95, 100.0, 'EDP', 'Women', {'floral'}, {'white', 'sandalwood', 'vanilla', 'musk', 'patchouli'}, {'strawberries', 'jasmine', 'cumin'}, 5.0, 'noon', '4.2', '98.1K']
# ['41', 'BENTLEY', 'Azure', 387.0, 107.0, 100.0, 'EDT', 'Men', {'citrus'}, {'orcanox', 'bean', 'cashmere wood', 'tonka'}, {'tea accord', 'pimento', 'sage', 'clary', 'lavender'}, 4.6, 'Cute Shop', '4.1', '538']
# ['42', 'VERSACE', 'Dylan Blue', 85.0, 20.5, 5.0, 'EDT', 'Men', {'citrus'}, {'saffron', 'tonka beans', 'frankincense', 'musk'}, {'black pepper', 'violet leaves', 'ambroxan', 'patchouli', 'papyrus'}, 4.4, 'Princess of beauty', '4.2', '467']
# ['43', 'Estee Lauder', 'Modern Muse', 450.0, 164.4, 50.0, 'EDP', 'Women', {'floral'}, {'patchouli', 'woody notes', 'amber', 'musk'}, {'lily', 'honey suckle', 'tuberose', 'jasmine sambac'}, 5.0, 'King-Perfume', '3.9', '450']
# ['44', 'Yves Saint Laurent', "La Nuit De L'Homme L'Intense", 583.0, 204.0, 100.0, 'EDP', 'Men', {'vanilla'}, {'patchouli', 'tonka bean'}, {'vanilla', 'sage'}, 5.0, 'Parfume-Stor', '4.1', '319']
# ['45', 'Juicy Couture', 'Vivi La Juicy Limited Edition', 235.0, 154.1, 100.0, 'EDP', 'Women', {'floral'}, {'amber', 'caramel', 'pralines', 'sandalwood', 'vanilla'}, {'honeysuckle', 'jasmine', 'gardenia'}, 5.0, 'AMLAQ', '3.9', '135']
# ['46', 'Laura Mars', 'Splandid', 36.0, 36.0, 100.0, 'EDP', 'Women', {'floral'}, {'amber', 'vanilla'}, {'geranium', 'ylangylan', 'jasmine', 'neroli'}, 5.0, 'hadayiq baris', '3.8', '122']
# ['47', 'GIORGIO ARMANI', 'Stronger With You', 415.0, 170.0, 100.0, 'EDT', 'Men', {'vanilla'}, {'guaiac wood', 'chestnut', 'cedar', 'vanilla', 'amber wood'}, {'cinnamon', 'sage', 'melon', 'pineapple', 'lavender'}, 4.5, 'hadayiq baris', '3.8', '122']
# ['48', 'CHLOE', 'Chloe', 631.0, 186.0, 75.0, 'EDP', 'Women', {'floral'}, {'cedar', 'amber'}, {'lilyofthevalley', 'rose', 'magnolia'}, 3.5, 'عا?? ا??شا??ر', '3.5', '75']
# ['49', 'HERMES', "Terre D'Hermes", 15.0, 9.55, 2.0, 'EDT', 'Men', {'citrus'}, {'patchouli', 'benzoin', 'cedar', 'vetiver'}, {'pepper', 'pelargonium'}, 5.0, 'beautiful lady', '3.8', '23']
# ['50', 'Elizabeth Arden', '5Th Avenue', 135.0, 89.4, 125.0, 'EDP', 'Women', {'floral'}, {'amber', 'iris', 'clove', 'sandalwood', 'vanilla', 'musk'}, {'peach', 'jasmine', 'carnation', 'nutmeg', 'ylangylang', 'violet', 'tuberose', 'bulgarian rose'}, 3.8, 'noon', '4.2', '98.1K']
# ['51', 'VERSACE', 'Dylan Blue', 425.0, 217.85, 100.0, 'EDT', 'Men', {'fresh'}, {'saffron', 'tonka bean', 'incense', 'musk'}, {'violet leaf', 'ambroxan', 'black pepper', 'patchouli', 'papyrus'}, 4.6, 'noon', '4.2', '98.1K']
# ['52', 'Benetton', 'Hot Gold', 45.0, 27.45, 100.0, 'EDT', 'Women', {'fresh'}, {'sandalwood', 'amber', 'musk'}, {'rose', 'carambola', 'mimosa'}, 4.4, 'noon', '4.2', '98.1K']
# ['53', 'PACO RABANNE', 'Invictus', 395.0, 210.0, 100.0, 'EDT', 'Men', {'citrus'}, {'guaiac', 'patchouli', 'heart', 'wood'}, {'accord', 'zests', 'ambregris', 'grapefruit'}, 4.8, 'Boutique Wareef', '3.8', '98']
# ['54', 'Roberto Cavalli', 'Nero Assoluto', 264.0, 129.55, 75.0, 'EDP', 'Women', {'arabian'}, {'woodsy notes', 'ebony'}, {'vanilla'}, 5.0, 'noon', '4.2', '98.1K']
# ['55', 'DORALL COLLECTION', 'Scholar', 19.0, 9.45, 100.0, 'EDT', 'Men', {'floral'}, {'woodyamber', 'sandalwood', 'moss', 'dry woods.', 'musk', 'patchouli'}, {'peach', 'green notes', 'apple', 'jasmine', 'lavender', 'muguet', 'dried fruits.'}, 5.0, 'B.A.G', '3.7', '14.1K']
# ['56', 'Calvin Klein', 'Eternity', 131.0, 100.0, 100.0, 'EDT', 'Men', {'floral'}, {'amber', 'brazilian', 'vetiver', 'sandalwood', 'rosewood', 'musk'}, {'coriander', 'jasmine', 'sage', 'lily', 'geranium', 'orange blossom', 'lilyofthevalley', 'basil', 'juniper berries'}, 4.0, 'hadayiq baris', '3.8', '122']
# ['57', 'Juicy Couture', 'Viva La Juicy Noir', 490.0, 144.45, 100.0, 'EDP', 'Women', {'fruity'}, {'sandalwood', 'amber', 'vanilla', 'caramel'}, {'honeysuckle', 'jasmine', 'gardenia'}, 4.9, 'Rose Gallary', '3.5', '63']
# ['58', 'PACO RABANNE', 'Lady Million', 535.0, 210.0, 80.0, 'EDP', 'Women', {'floral'}, {'gardenia'}, {'orange', 'flower', 'jasmine', 'african', 'arabic'}, 4.7, 'Beauty Ideas', '3.9', '61']
# ['59', 'Giorgio Beverly Hills', 'giorgio', 120.0, 120.0, 90.0, 'EDT', 'Women', {'floral'}, {'amber', 'cedar', 'sandalwood', 'vanilla', 'musk', 'patchouli', 'oakmoss'}, {'gardenia', 'rose', 'jasmine', 'seductive tuberose', 'orchid', 'ylangylang'}, 5.0, 'Faces', '3.9', '61']
# ['60', 'Guerlain', 'Idylle', 430.0, 256.0, 100.0, 'EDP', 'Women', {'floral'}, {'sandalwood', 'amber', 'accord'}, {'jasmine', 'ylang', 'magnolia'}, 4.3, 'MOON LIGHT', '3.9', '33']
# ['61', 'Yves Saint Laurent', 'Libre', 655.0, 410.0, 90.0, 'EDP', 'Women', {'floral'}, {'amber', 'vanilla', 'ambergris', 'musk'}, {'lavender', 'orange blossom', 'jasmine'}, 4.9, 'Parfume-Stor', '4.2', '25']
# ['62', 'Jean Paul GAULTIER', 'Scandal', 400.0, 288.0, 50.0, 'EDP', 'Women', {'floral'}, {'patchouli', 'caramel', 'licorice', 'beeswax'}, {'peach', 'gardenia', 'jasmine', 'honey', 'orange blossom'}, 5.0, 'Shopping life', '4.2', '20']
# ['63', 'BURBERRY', 'Mr. Burberry', 515.0, 179.95, 100.0, 'EDP', 'Men', {'woody'}, {'amber', 'cinnamon', 'vetiver', 'benzoin', 'sandalwood', 'patchouli'}, {'cedar', 'lavender', 'nutmeg'}, 4.5, 'noon', '4.2', '98.1K']
# ['64', 'Ajmal', 'Raindrops', 97.0, 47.95, 50.0, 'EDP', 'Women', {'fruity'}, {'floral ambery woody'}, {'animalistic floral'}, 4.7, 'noon', '4.2', '98.1K']
# ['65', 'GUCCI', 'Guilty Absolute', 552.0, 332.3, 90.0, 'EDP', 'Women', {'spicy'}, {'patchouli', 'amber'}, {'vetiver', 'woody notes', 'cypress', 'bulgarian rose'}, 4.2, 'Star.perfume', '3.9', '537']
# ['66', 'BURBERRY', 'Mr. Burberry', 295.0, 200.0, 100.0, 'EDP', 'Men', {'woody'}, {'amber', 'vetiver', 'sandalwood', 'patchouli', 'benzoin cinnamon'}, {'cedar', 'lavender', 'nutmeg'}, 5.0, 'Star.perfume', '3.9', '537']
# ['67', 'VERSACE', 'Dylan Blue', 85.0, 20.5, 5.0, 'EDT', 'Men', {'citrus'}, {'saffron', 'tonka beans', 'frankincense', 'musk'}, {'black pepper', 'violet leaves', 'ambroxan', 'patchouli', 'papyrus'}, 4.4, 'Princess of beauty', '3.5', '467']
# ['68', 'J.CASANOVA', 'ICQ', 76.3, 76.3, 100.0, 'EDT', 'Men', {'fresh'}, {'sandalwood', 'wood', 'cedar wood', 'animal', 'patchouli'}, {'cyclamen', 'ylangylang', 'rosewood', 'jasmin', 'floral'}, 5.0, 'Parisian Store', '3.9', '425']
# ['69', 'UNITED COLORS OF BENETTON', 'Cold', 51.0, 27.95, 100.0, 'EDT', 'Women', {'spicy'}, {'amber', 'vetiver', 'vanilla', 'musk', 'patchouli', 'frankincense'}, {'pimiento', 'coriander', 'cumin'}, 4.0, 'top langri', '4.2', '347']
# ['70', 'YSL', 'Supreme Bouquet', 1215.0, 699.0, 75.0, 'EDP', 'Unisex', {'woody'}, {'patchouli', 'amber', 'musk'}, {'ylangylang', 'jasmine', 'tuberose'}, 5.0, 'PARFUM.1990', '3.5', '244']
# ['71', 'TOMMY HILFIGER', 'Tommy', 340.0, 129.0, 100.0, 'EDT', 'Men', {'spicy'}, {'cotton', 'amber', 'cactus'}, {'apple', 'rose', 'cranberry'}, 4.4, 'AMLAQ', '3.9', '135']
# ['72', 'RALPH LAUREN', 'Safari', 541.0, 178.0, 125.0, 'EDT', 'Men', {'woody'}, {'amber', 'cedar', 'sandalwood', 'musk', 'patchouli', 'leather', 'oakmoss'}, {'cinnamon', 'tarragon', 'rose', 'jasmine', 'carnation', 'cyclamen'}, 3.5, 'Pinch Of Perfum', '3.5', '75']
# ['73', 'EMPORIO ARMANI', 'Stronger With You', 415.0, 175.85, 100.0, 'EDT', 'Men', {'floral'}, {'amberwood', 'vanilla', 'cedar', 'chestnut'}, {'melon', 'sage', 'pineapple'}, 4.5, 'flower', '3.8', '66']
# ['74', 'TED LAPIDUS', 'Rumba Passion Ted Lapidus', 140.0, 95.0, 100.0, 'EDT', 'Women', {'floral'}, {'patchouli', 'vanilla', 'honey'}, {'rose', 'jasmine'}, 5.0, 'Beauty Gallery', '3.7', '59']
# ['75', 'HUGO BOSS', 'Dark Blue', 159.0, 129.0, 75.0, 'EDT', 'Men', {'citrus'}, {'patchouli', 'benzoin', 'suede', 'olibanum'}, {'cypress', 'pelargonium', 'sage'}, 4.5, 'Diorworld', '3.6', '30']
# ['76', 'VERSACE', 'Dylan Blue', 425.0, 217.85, 100.0, 'EDT', 'Men', {'fresh'}, {'saffron', 'tonka bean', 'incense', 'musk'}, {'violet leaf', 'ambroxan', 'black pepper', 'patchouli', 'papyrus'}, 4.6, 'noon', '4.2', '98.1K']
# ['77', 'BOUCHERON', 'Quatre', 462.0, 169.75, 100.0, 'EDP', 'Women', {'floral'}, {'cashmere', 'vanilla', 'caramel', 'white musk'}, {'apple', 'rose', 'jasmine', 'fishing'}, 4.9, 'noon', '4.2', '98.1K']
# ['78', 'DORALL COLLECTION', 'Molto Carina', 27.0, 8.55, 100.0, 'EDT', 'Women', {'woody'}, {'lactone', 'musk', 'woody amber'}, {'tropical fruits', 'peach', 'jasmin', 'water'}, 4.0, 'B.A.G', '3.7', '14.1K']
# ['79', 'armani', 'Stronger With You Intensely', 457.0, 336.0, 100.0, 'EDP', 'Men', {'aromatic'}, {'ambery woods'}, {'vanilla'}, 4.8, 'flower', '3.9', '537']
# ['80', 'PACO RABANNE', '1 Million', 395.0, 173.0, 100.0, 'EDT', 'Men', {'woody'}, {'indian patchouli', 'amber', 'notes', 'leather', 'woody'}, {'bark', 'rose absolute', 'musk', 'cinnamon'}, 3.8, 'Al-Najm', '3.7', '347']
# ['81', 'VALENTINO', 'Valentina', 500.0, 241.0, 80.0, 'EDP', 'Women', {'floral'}, {'virginia cedar', 'vanilla', 'amber'}, {'african orange flower', 'jasmine', 'strawberry', 'tuberose'}, 5.0, 'top langri', '3.7', '347']
# ['82', 'Ard Al Zaafaran', 'Oud 24 Hours', 47.0, 47.0, 100.0, 'EDP', 'Unisex', {'fresh'}, {'amber', 'incense', 'sandalwood', 'agarwood', 'oud', 'patchouli'}, {'gardenia', 'spicy notes', 'jasmine', 'fruity notes', 'ylangylang'}, 4.0, 'Attractive perfume', '3.5', '244']
# ['83', 'DKNY', 'Be Delicious', 185.0, 148.35, 100.0, 'EDP', 'Women', {'floral'}, {'white', 'amber', 'woods'}, {'apple', 'rose', 'violet', 'tuberose', 'white muguet'}, 4.8, 'AMLAQ', '3.9', '135']
# ['84', 'Estee Lauder', 'Modern Muse', 584.0, 239.7, 100.0, 'EDP', 'Women', {'floral'}, {'amber', 'woodsy note', 'vanilla', 'musk', 'patchouli'}, {'chinee jasmine', 'honeysuckles', 'jasmine sambac', 'lily', 'flower petals', 'tuberose'}, 4.5, 'AMLAQ', '3.9', '135']
# ['85', 'CAROLINA HERRERA', 'Good Girl', 565.0, 213.15, 80.0, 'EDP', 'Women', {'arabian'}, {'cashmere wood', 'praline', 'cinnamon', 'cocoa', 'cedar', 'sandalwood', 'tonka bean'}, {'orris', 'jasmine sambac', 'tuberose', 'orange blossom', 'bulgarian rose'}, 4.8, 'hadayiq baris', '3.8', '122']
# ['86', 'BURBERRY', 'Mr.Burberry', 515.0, 199.9, 100.0, 'EDP', 'Men', {'woody'}, {'vetiver', 'guaiac wood', 'sandalwood'}, {'cedar', 'birch leaf', 'nutmeg oil'}, 4.6, 'Faces', '3.9', '61']
# ['87', 'Guerlain', 'Ideal', 560.0, 223.0, 100.0, 'EDP', 'Men', {'fruity'}, {'leather', 'sandalwood', 'tonka beans'}, {'cherry', 'vanilla', 'incense', 'bulgarian rose'}, 4.8, 'Majestueuse', '4.8', '21']
# ['88', 'GIORGIO ARMANI', 'Acqua Di Gio', 660.0, 464.9, 200.0, 'EDT', 'Men', {'citrus'}, {'cedar', 'amber', 'oak moss', 'musk'}, {'love', 'coriander', 'small coconut', 'peach', 'rose', 'flower', 'sea notes', 'violet', 'freesia'}, 3.7, 'Beautiful Live', '412', '7']
# ['89', 'ELIE SAAB', 'Girl of Now Shine', 504.0, 192.0, 91.0, 'EDP', 'Women', {'arabian'}, {'iris', 'jasmine', 'sweet', 'vanilla', 'patchouli'}, {'ylangylang', 'roasted', 'almonds'}, 5.0, 'flower', '4.2', '98']
# ['90', 'NARCISO RODRIGUEZ', 'Narciso Rodriguez', 436.0, 215.75, 50.0, 'EDP', 'Women', {'spicy'}, {'patchouli', 'sandalwood'}, {'amber', 'musk'}, 4.3, 'noon', '4.2', '98.1K']
# ['91', 'Ajmal', 'Raindrops', 97.0, 47.95, 50.0, 'EDP', 'Women', {'fruity'}, {'floral ambery woody'}, {'animalistic floral'}, 4.7, 'noon', '4.2', '98.1K']
# ['92', 'Roberto Cavalli', 'Uomo', 349.0, 126.0, 100.0, 'EDT', 'Men', {'floral'}, {'cedar'}, {'honey', 'lavender'}, 5.0, 'noon', '4.2', '98.1K']
# ['93', 'MONTBLANC', 'Emblem Absolu', 395.0, 116.0, 100.0, 'EDT', 'Men', {'spicy'}, {'patchouli', 'moss', 'vetiver'}, {'pink pepper', 'lavender', 'fruits', 'honey'}, 4.7, 'Modon', '3.9', '537']
# ['94', 'LACOSTE', 'Eau de Lacoste L. 12.12 Noir', 330.0, 85.0, 100.0, 'EDT', 'Men', {'spicy'}, {'coumarin', 'cashmeran', 'patchouli', 'dark chocolate'}, {'verbena', 'lavender', 'basil'}, 4.8, 'Al-Najm', '3.7', '347']
# ['95', 'Calvin Klein', 'CKIN2U', 148.0, 82.9, 100.0, 'EDT', 'Men', {'citrus'}, {'vetiver', 'white', 'cedar', 'musk'}, {'cacao pod'}, 5.0, 'AMLAQ', '3.9', '135']
# ['96', 'Roberto Cavalli', 'Florence', 230.0, 166.8, 75.0, 'EDP', 'Women', {'floral'}, {'patchouli', 'amber', 'musk'}, {'hibiscus seed', 'orange blossom', 'grapefruit blossom'}, 4.6, 'AMLAQ', '3.9', '135']
# ['97', 'TOMMY HILFIGER', 'Tommy Hilfiger', 221.0, 124.9, 100.0, 'EDT', 'Men', {'spicy'}, {'cotton', 'amber', 'cactus', 'flower'}, {'cranberry', 'granny', 'apple', 'rose', 'smith'}, 4.1, 'AMLAQ', '3.9', '135']
# ['98', 'LE CHAMEAU', 'Atelier Intense', 88.0, 71.25, 80.0, 'EDT', 'Men', {'arabian'}, {'amber', 'musk', 'oakmoss', 'vetyver'}, {'ceadarwood', 'sandalwood', 'spicy', 'tonka'}, 5.0, 'Emper Perfumes', '3.5', '88']
# ['99', 'LE CHAMEAU', 'Genesis Oud Malaki', 73.0, 73.0, 99.0, 'EDT', 'Unisex', {'arabian'}, {'vetiver', 'musk'}, {'apple', 'patchouli', 'agarwood', 'amber'}, 2.0, 'Queen Line', '3.8', '81']
# ['100', 'AVON', 'Tomorrow', 130.0, 70.0, 50.0, 'EDP', 'Women', {'floral'}, {'rose', 'balsamic', 'floral', 'powdery', 'woody'}, {'musk'}, 4.5, 'Tiffany', '3.7', '54']
# ['101', 'PACO RABANNE', 'Invictus', 395.0, 210.0, 100.0, 'EDT', 'Men', {'citrus'}, {'guaiac', 'patchouli', 'heart', 'wood'}, {'accord', 'zests', 'ambregris', 'grapefruit'}, 4.8, 'Boutique Wareef', '3.8', '98']
# ['102', 'Salvatore Ferragamo', 'Signorina Eleganza', 326.0, 153.3, 100.0, 'EDP', 'Women', {'fruity'}, {'patchouli', 'leather', 'white'}, {'petals', 'golden', 'almond', 'powder', 'osmanthus'}, 5.0, 'noon', '4.2', '98.1K']
# ['103', 'Carrera', 'Pour Homme', 59.0, 43.5, 100.0, 'EDT', 'Men', {'woody'}, {'cedar', 'sandalwood', 'musk', 'leather', 'tonka bean', 'oakmoss'}, {'anise', 'cloves', 'jasmine', 'ginger'}, 5.0, 'KAYA', '4.3', '4K']
# ['104', 'DORALL COLLECTION', 'Nashwa', 43.0, 14.2, 100.0, 'EDT', 'Women', {'woody'}, {'amber', 'sandalwood', 'vanilla', 'musk', 'patchouli'}, {'valley', 'gardenia', 'the', 'jasmine', 'lily', 'magnolia', 'freesia'}, 5.0, 'B.A.G', '3.7', '14.1K']
# ['105', 'Calvin Klein', 'Euphoria', 289.0, 94.55, 100.0, 'EDT', 'Men', {'woody'}, {'amber', 'brazilian', 'redwood', 'suede', 'patchouli'}, {'black basil', 'sage', 'cedar'}, 4.7, 'Star.perfume', '4.2', '537']
# ['106', 'HUGO BOSS', 'XX', 295.0, 158.65, 100.0, 'EDT', 'Women', {'fruity'}, {'sandalwood', 'amber', 'musk'}, {'rose', 'jasmine', 'rice'}, 4.5, 'Star.perfume', '3.9', '537']
# ['107', 'Sedr Al-Khaleej Perfumes', 'Moon Light', 55.0, 34.3, 100.0, 'EDP', 'Women', {'citrus'}, {'cashmere wood', 'praline', 'cinnamon', 'cocoa', 'cedar', 'sandalwood', 'tonka bean'}, {'orris', 'jasmine sambac', 'tuberose', 'orange blossom', 'bulgarian rose'}, 5.0, 'SEDR', '4.2', '288']
# ['108', 'Dunhill', 'Desire', 230.0, 84.95, 100.0, 'EDT', 'Men', {'fresh'}, {'labdanum', 'vanilla', 'musk'}, {'patchouli', 'rose', 'teakwood'}, 4.2, 'hadayiq baris', '3.8', '122']
# ['109', 'Dior', 'Sauvage', 1176.0, 240.85, 100.0, 'EDT', 'Men', {'fresh'}, {'cedar', 'labdanum', 'ambroxan'}, {'pepper', 'patchouli', 'elemi', 'pink pepper', 'lavender', 'vetiver', 'geranium', 'sichuan'}, 3.8, 'ثر?ة ا?ج?ا?', '3.9', '61']
# ['110', 'TRUSSARDI', 'My Land', 300.0, 164.0, 100.0, 'EDT', 'Men', {'woody'}, {'vetiver', 'leather', 'bean', 'tonka'}, {'lavender', 'violet', 'calone'}, 4.5, 'Beautiful Live', '412', '7']
# ['111', 'Dupont', 'Passenger', 95.0, 95.0, 100.0, 'EDT', 'Men', {'woody'}, {'guaiac wood', 'benzoin'}, {'pepper', 'cardamom', 'lavender', 'pink', 'ginger'}, 4.5, 'Beautiful Live', '412', '7']
# ['112', 'ANGEL SCHLESSER', 'Essential', 287.0, 103.95, 100.0, 'EDP', 'Women', {'oriental'}, {'vetiver', 'sandal wood', 'musk'}, {'peony', 'rose', 'violet', 'bulgarian', 'freesia'}, 4.6, 'noon', '4.2', '98.1K']
# ['113', 'Calvin Klein', 'Euphoria', 220.0, 91.95, 100.0, 'EDT', 'Men', {'woody'}, {'patchouli', 'amber', 'brazilian redwood', 'suede'}, {'black basil', 'sage', 'cedar'}, 5.0, 'noon', '4.2', '98.1K']
# ['114', 'PACO RABANNE', 'Pour Homme', 226.0, 136.05, 100.0, 'EDT', 'Men', {'woody'}, {'honey', 'amber', 'musk', 'oakmoss'}, {'geranium', 'lavender', 'tonka bean'}, 4.5, 'noon', '4.2', '98.1K']
# ['115', 'MONTBLANC', 'Starwalker', 240.0, 125.55, 75.0, 'EDT', 'Men', {'woody'}, {'nutmeg', 'fir resin', 'amber', 'ginger'}, {'cedar', 'sandalwood', 'white musk'}, 5.0, 'noon', '4.2', '98.1K']
# ['116', 'DORALL COLLECTION', 'Classic Black', 9.0, 8.8, 100.0, 'EDT', 'Men', {'fresh'}, {'patchouli', 'cashmere wood', 'chocolate', 'tonka bean'}, {'verbena', 'lavender', 'basil'}, 4.0, 'the beauty', '3.9', '538']
# ['117', 'S.T.Dupont', 'Essence Pure', 215.0, 84.6, 100.0, 'EDT', 'Women', {'citrus'}, {'patchouli', 'amber', 'vanilla', 'cedar'}, {'rose', 'jasmine'}, 4.4, 'the beauty', '4.1', '538']
# ['118', 'S.T.Dupont', 'Passenger Spray', 220.0, 124.7, 100.0, 'EDP', 'Women', {'fruity'}, {'sandalwood', 'musk'}, {'gardenia', 'iris', 'rose', 'redolent', 'cyclamen'}, 5.0, 'AMLAQ', '3.9', '135']
# ['119', 'DAVIDOFF', 'Zino', 116.0, 81.55, 125.0, 'EDT', 'Men', {'woody'}, {'amber', 'cedar', 'vanilla', 'tonka', 'patchouli', 'sandal'}, {'geranium', 'rose', 'muguet', 'jasmine'}, 3.4, 'AMLAQ', '3.9', '135']
# ['120', 'Ajmal', 'Evoke', 150.05, 150.05, 75.0, 'EDP', 'Women', {'floral'}, {'patchouli', 'moss', 'vanilla'}, {'rose', 'jasmine', 'orris'}, 5.0, 'BOUTIQUE PERFUMES', '4.3', '118']
# ['121', 'Guerlain', 'Idylle', 725.0, 259.7, 100.0, 'EDP', 'Women', {'floral'}, {'patchouli', 'musk'}, {'valley', 'the', 'peony', 'jasmine', 'lily', 'lilac'}, 5.0, 'ثر?ة ا?ج?ا?', '3.8', '76']
# ['122', 'CHOPARD', 'Wish', 182.0, 96.0, 75.0, 'EDP', 'Women', {'oriental'}, {'amber', 'caramel', 'sandalwood', 'vanilla', 'patchouli'}, {'valley', 'the', 'jasmine', 'milk', 'orchid', 'honey', 'lily', 'osmanthus', 'violet', 'heliotrope', 'magnolia'}, 4.8, 'Dior Fragrances', '3.9', '69']
# ['123', 'PACO RABANNE', 'Olympêa', 455.0, 150.0, 80.0, 'EDP', 'Women', {'floral'}, {'cashmere', 'sandalwood', 'ambergris'}, {'vanilla'}, 4.5, 'Asrar Aljamal', '3.8', '61']
# ['124', 'CHOPARD', 'Happy Spirit', 230.0, 152.15, 75.0, 'EDP', 'Women', {'floral'}, {'amber', 'cashmere wood', 'musk'}, {'honeysuckle', 'osmanthus'}, 4.4, 'noon', '4.2', '98.1K']
# ['125', 'CARTIER', 'Pasha de Cartier', 290.0, 185.25, 100.0, 'EDT', 'Men', {'aromatic'}, {'patchouli', 'sandalwood', 'labdanum', 'oakmoss'}, {'coriander', 'brazilian rosewood'}, 4.3, 'noon', '4.2', '98.1K']
# ['126', 'PACO RABANNE', 'Olympea', 458.0, 134.0, 80.0, 'EDP', 'Women', {'floral'}, {'cashmere', 'sandalwood', 'ambergris'}, {'salted vanilla'}, 4.0, 'Number One', '4.2', '1.3K']
# ['127', 'jennifer lopez', 'Live', 161.0, 104.0, 100.0, 'EDP', 'Women', {'fruity'}, {'creamy buttery lactonic caramel', 'rich', 'tonka bean', 'sensual'}, {'violet', 'uity red currant blossoms'}, 5.0, 'Star.perfume', '3.9', '537']
# ['128', 'Yves Saint Laurent', 'Black Opium Nuit Blanche', 620.0, 266.9, 90.0, 'EDP', 'Women', {'spicy'}, {'sandalwood', 'white musk', 'vanilla absolute'}, {'black opium coffee', 'orange blossom absolute'}, 4.5, 'Al-Najm', '3.7', '347']
# ['129', 'LACOSTE', 'Eau de Lacoste L. 12.12 Noir', 330.0, 85.0, 100.0, 'EDT', 'Men', {'spicy'}, {'coumarin', 'cashmeran', 'patchouli', 'dark chocolate'}, {'verbena', 'lavender', 'basil'}, 4.8, 'Al-Najm', '3.7', '347']
# ['130', 'Calvin Klein', 'Euphoria Intense', 440.0, 99.0, 100.0, 'EDT', 'Men', {'spicy'}, {'cashmere woods', 'amber', 'burnt', 'australian', 'sandalwood', 'madagascar vanilla'}, {'black basil', 'sage', 'cedar', 'vetiver'}, 4.2, 'Al-Najm', '3.7', '347']
# ['131', 'PACO RABANNE', 'Paco Rabanne', 250.0, 133.7, 100.0, 'EDT', 'Men', {'woody'}, {'tobacco', 'musk', 'oakmoss'}, {'lavender', 'thyme', 'tarragon'}, 4.4, 'AMLAQ', '3.9', '135']
# ['132', 'Ajmal', 'Sacrifice', 75.9, 75.9, 50.0, 'EDP', 'Women', {'floral'}, {'oriental', 'musky', 'woody'}, {'musky', 'floral'}, 4.5, 'neo lek', '3.5', '88']
# ['133', 'BVLGARI', 'Petits Et Mamans', 327.0, 197.75, 100.0, 'EDT', 'Women', {'floral'}, {'vanilla', 'iris'}, {'white peach'}, 4.8, 'Tiffany', '4.2', '75']
# ['134', 'Ferrari', 'Scuderia Black', 163.0, 98.5, 125.0, 'EDT', 'Men', {'fruity'}, {'cedar', 'amber', 'vanilla', 'musk'}, {'cardamom', 'rose', 'jasmine', 'cinnamon'}, 4.0, 'Beauty Gallery', '3.7', '59']
# ['135', 'TRUSSARDI', 'My Name', 308.0, 228.0, 50.0, 'EDP', 'Women', {'floral'}, {'vanilla', 'dry amber'}, {'musk', 'lilac'}, 4.6, 'Beautiful Live', '4.2', '7']
# ['136', 'VERSACE', 'Crystal Noir', 342.0, 183.45, 50.0, 'EDT', 'Women', {'arabian'}, {'sandalwood', 'musk', 'amber'}, {'orange blossom', 'gardenia', 'peony', 'coconut'}, 3.9, 'noon', '4.2', '98.1K']
# ['137', 'Calvin Klein', 'Intense Euphoria', 290.0, 109.95, 100.0, 'EDT', 'Men', {'spicy'}, {'amber', 'labdanum', 'agarwood', 'patchouli', 'myrrh'}, {'black basil', 'sage', 'cedar', 'vetiver'}, 4.4, 'noon', '4.2', '98.1K']
# ['138', 'PACO RABANNE', 'One Million Lucky', 435.0, 257.15, 100.0, 'EDT', 'Men', {'woody'}, {'patchouli', 'white cedar', 'vanilla', 'amber wood'}, {'cedar', 'hazelnut', 'jasmine'}, 4.7, 'noon', '4.2', '98.1K']
# ['139', 'HERMES', "Terre D' Hermes", 474.0, 173.0, 100.0, 'EDT', 'Men', {'citrus'}, {'patchouli', 'woody notes', 'cedar'}, {'geranium'}, 3.9, 'Boutique Wareef', '4.2', '98.1K']
# ['140', 'Alrehab', 'Anfas Aloud', 215.0, 85.5, 60.0, 'EDP', 'Unisex', {'arabian'}, {'oud'}, {'bergamot'}, 5.0, 'Parisian Store', '4.1', '425']
# ['141', 'EMPORIO ARMANI', "Because It's You", 483.0, 154.7, 100.0, 'EDP', 'Women', {'floral'}, {'amberwood', 'vanilla', 'musk'}, {'rose'}, 4.9, 'Al-Najm', '3.7', '347']
# ['142', 'Genie', 'London Burberry', 29.0, 14.95, 25.0, 'EDP', 'Women', {'floral'}, {'wood', 'musk'}, {'tiare', 'peony', 'flower', 'jasmine', 'soft'}, 4.7, 'moon perfume', '3.7', '199']
# ['143', 'Roberto Cavalli', 'Women', 430.0, 103.0, 75.0, 'EDP', 'Women', {'arabian'}, {'benzoin', 'tonka beans', 'vanilla'}, {'orange tree blossom'}, 5.0, 'rich&light', '3.8', '69']
# ['144', 'LALIQUE', 'Lalique', 541.0, 249.0, 100.0, 'EDP', 'Women', {'woody'}, {'sandalwood', 'vanilla', 'white musk'}, {'pear', 'blackberry', 'cassis'}, 4.4, 'Faces', '3.9', '61']
# ['145', 'Franck Olivier', 'Oud Touch', 93.0, 93.0, 100.0, 'EDP', 'Men', {'woody'}, {'amber', 'vanilla', 'musk'}, {'rose', 'jasmine', 'olibanum', 'violet', 'patchouli'}, 5.0, 'Faces', '3.9', '61']
# ['146', 'TOMMY HILFIGER', 'Tommy', 340.0, 130.0, 100.0, 'EDT', 'Men', {'spicy'}, {'amber', 'cactus', 'cotton plant blossom'}, {'apple', 'rose', 'cranberries'}, 5.0, 'Faces', '3.9', '61']
# ['147', 'Elizabeth Arden', '5th Avenue', 155.0, 93.0, 75.0, 'EDP', 'Women', {'floral'}, {'amber', 'iris', 'sandalwood', 'tibetan musk', 'vanilla'}, {'peach', 'bulgarian pink violet', 'indian tuberose', 'jasmine', 'carnation', 'nutmeg', 'ylangylang'}, 4.0, 'Ryhana Perfume', '4.2', '25']
# ['148', 'ELIE SAAB', 'Girl Of Now', 561.0, 250.0, 90.0, 'EDP', 'Women', {'floral'}, {'patchouli', 'cashmeran', 'tonka bean', 'almod milk'}, {'magnoli', 'orange blossom', 'almond'}, 4.5, 'Beuatyone1', '3.5', '98']
# ['149', 'PACO RABANNE', 'One Million', 426.0, 287.95, 200.0, 'EDT', 'Men', {'woody'}, {'blonde leather patchouli white woods amber'}, {'rose', 'absolute', 'spices', 'cinnamon'}, 5.0, 'noon100  % original genuine product', '4.2', '98.1K']
# ['150', 'Calvin Klein', 'Euphoria', 289.0, 94.55, 100.0, 'EDT', 'Men', {'woody'}, {'amber', 'brazilian', 'redwood', 'suede', 'patchouli'}, {'black basil', 'sage', 'cedar'}, 4.7, 'Star.perfume', '3.9', '537']
# ['151', 'cacharel', 'Noa', 299.0, 154.75, 100.0, 'EDT', 'Women', {'fresh'}, {'transparent', 'coffee', 'incense touches', 'woodsy'}, {'ylangylang', 'rose', 'white flowers'}, 4.5, 'Star.perfume', '3.9', '537']
# ['152', 'GUESS', 'Seductive Homme', 134.0, 91.75, 100.0, 'EDT', 'Men', {'spicy'}, {'patchouli', 'sandalwood', 'musk', 'amber'}, {'vetiver', 'violet leaf', 'orchid'}, 4.5, 'Star.perfume', '3.9', '537']
# ['153', 'Al Fakhr', 'Ameer Al Oud Khususi', 28.0, 12.0, 100.0, 'EDP', 'Unisex', {'woody'}, {'cedarwood', 'sandalwood'}, {'cardamom', 'black pepper'}, 4.1, 'kikup', '3.9', '425']
# ['154', 'Alrehab', 'Anfas Aloud', 215.0, 85.5, 60.0, 'EDP', 'Unisex', {'arabian'}, {'oud'}, {'bergamot'}, 5.0, 'Parisian Store', '3.7', '425']
# ['155', 'Givenchy', 'Pour Homme', 219.0, 117.0, 100.0, 'EDT', 'Men', {'spicy'}, {'ceder', 'labdanum'}, {'vetiver', 'lavender'}, 4.4, 'Al-Najm', '3.7', '347']
# ['156', 'Rasasi', 'Blue', 36.95, 36.95, 100.0, 'EDT', 'Men', {'spicy'}, {'amber', 'woody'}, {'pepper', 'coriander', 'rose', 'jasmine', 'geranium'}, 5.0, 'hadayiq baris', '3.8', '122']
# ['157', 'GIORGIO ARMANI', 'Eau Pour Homme Reno 2013', 361.0, 186.0, 50.0, 'EDT', 'Men', {'citrus'}, {'patchouli', 'sandalwood', 'oakmoss'}, {'lily', 'cloves', 'nutmeg'}, 4.7, 'MOON LIGHT', '3.8', '76']
# ['158', 'LACOSTE', 'Touch Of Pink', 238.0, 95.0, 50.0, 'EDT', 'Women', {'floral'}, {'vanilla', 'woodsymusk base'}, {'spicy', 'jasmine', 'unexpected carrot', 'coriander'}, 4.6, 'Cute Shop', '4.4', '59']
# ['159', 'GUESS', 'Gold', 341.0, 119.0, 75.0, 'EDP', 'Women', {'floral'}, {'amber', 'vetiver', 'sandalwood', 'sensual', 'musk', 'patchouli'}, {'rose', 'jasmine', 'intoxicating', 'lotus', 'seductress'}, 4.9, 'Beautiful Live', '4.2', '7']
# ['160', 'BVLGARI', 'Goldea The Roman Night', 530.0, 229.25, 75.0, 'EDP', 'Women', {'floral'}, {'patchouli', 'moss', 'black musk', 'vetiver'}, {'rose', 'black peony', 'nightblooming jasmine', 'tuberose'}, 4.7, 'noon', '4.2', '98.1K']
# ['161', 'LACOSTE', 'Lacoste', 368.0, 115.0, 100.0, 'EDT', 'Men', {'citrus'}, {'amber', 'woody notes', 'cedar', 'vanilla', 'musk'}, {'almond', 'jasmine', 'ginger', 'black pepper'}, 4.6, 'noon', '4.2', '98.1K']
# ['162', 'Guerlain', 'Samsara', 400.0, 221.45, 100.0, 'EDP', 'Women', {'arabian'}, {'amber', 'sandal wood', 'vanilla', 'musk', 'tonka bean'}, {'luscious narcissus', 'cold woodsy iris', 'rose', 'jasmine', 'violet'}, 4.7, 'noon', '4.2', '98.1K']
# ['163', 'HUGO BOSS', 'The Scent', 535.0, 155.0, 100.0, 'EDP', 'Women', {'fruity'}, {'cacao'}, {'osmanthus'}, 4.5, 'noon', '4.2', '98.1K']
# ['164', 'JAGUAR', 'Classic Gold', 118.0, 79.95, 100.0, 'EDT', 'Men', {'woody'}, {'patchouli', 'vanilla', 'musk'}, {'orange blossom', 'teak wood'}, 4.7, 'Star.perfume', '3.9', '537']
# ['165', 'Franck Olivier', 'Frank Olivier', 139.0, 87.0, 75.0, 'EDP', 'Women', {'musk'}, {'sandalwood', 'vanilla', 'musk'}, {'ylangylang', 'rose', 'jasmine', 'heliotrope'}, 4.7, 'AMLAQ', '3.9', '135']
# ['166', 'CHOPARD', 'Happy Spirit Forever', 440.0, 98.1, 75.0, 'EDP', 'Women', {'oriental'}, {'patchouli', 'amber'}, {'blossom', 'rosemary', 'jasmine', 'orange'}, 4.9, 'AMLAQ', '3.9', '135']
# ['167', 'PACO RABANNE', 'Million', 295.0, 166.5, 50.0, 'EDP', 'Women', {'fresh'}, {'honey', 'patchouli'}, {'flower', 'jasmine', 'absolute', 'orange'}, 5.0, 'Number One', '4.3', '118']
# ['168', 'Pino Silvestre', 'Pino Silvester Original', 72.5, 72.5, 125.0, 'EDT', 'Men', {'woody'}, {'amber', 'cedar', 'beans', 'moss', 'musk', 'tonka'}, {'nutmeg', 'carnation', 'spicy', 'notes', 'thyme', 'geranium', 'fir', 'tree'}, 5.0, 'neo lek', '3.5', '88']
# ['169', 'MONTALE', 'Roses Musk', 375.0, 237.9, 100.0, 'EDP', 'Women', {'floral'}, {'musk'}, {'jasmine'}, 5.0, 'Lolita ShopNo Exchange or Return', '3.5', '75']
# ['170', 'Kenneth Cole', 'Black', 315.0, 177.9, 100.0, 'EDT', 'Men', {'floral'}, {'amber', 'leaf', 'suede', 'musk', 'violet'}, {'incense', 'woods', 'nutmeg', 'cedar', 'exotic', 'lotus'}, 4.5, 'Alabeer', '3.9', '33']
# ['171', 'Calvin Klein', 'Intense Euphoria', 290.0, 109.95, 100.0, 'EDT', 'Men', {'spicy'}, {'amber', 'labdanum', 'agarwood', 'patchouli', 'myrrh'}, {'black basil', 'sage', 'cedar', 'vetiver'}, 4.4, 'noon', '4.2', '98.1K']
# ['172', 'MONTBLANC', 'Legend', 445.0, 214.55, 200.0, 'EDT', 'Men', {'spicy'}, {'bean', 'sandalwood', 'tonka'}, {'coumarin', 'apple', 'rose', 'oak moss', 'fruits', 'dried', 'geranium', 'red'}, 4.5, 'noon', '4.2', '98.1K']
# ['173', 'Calvin Klein', 'Obsession', 231.0, 120.0, 125.0, 'EDT', 'Men', {'spicy'}, {'amber', 'sandalwood', 'vanilla', 'musk', 'patchouli'}, {'sage', 'pine', 'nutmeg', 'brazilian rosewood', 'myrrh', 'tree'}, 3.0, 'noon', '4.2', '98.1K']
# ['174', 'Lattafa', 'Sheikh Al Shuyukh', 63.0, 32.75, 50.0, 'EDP', 'Unisex', {'aromatic'}, {'vetiver', 'patchouli'}, {'rosemary', 'lavender sage'}, 4.8, 'noon', '4.2', '98.1K']
# ['175', 'Dolce & Gabbana', 'The One', 100.0, 100.0, 75.0, 'EDP', 'Women', {'fruity'}, {'cedar', 'tobacco', 'amber'}, {'cardamom', 'orange blossom', 'ginger'}, 5.0, 'Asrar Aljamal', '3.9', '537']
# ['176', 'Kenzo', 'World Intense', 500.0, 149.75, 75.0, 'EDP', 'Women', {'spicy'}, {'vanilla'}, {'jasmine', 'peony'}, 4.0, 'Star.perfume', '3.9', '537']
# ['177', 'Dolce & Gabbana', "L' Imperatrice 3", 370.0, 157.7, 100.0, 'EDT', 'Women', {'fruity'}, {'lemon tree', 'sandalwood', 'musk'}, {'cyclamen', 'watermelon', 'jasmine'}, 4.7, 'AMLAQ', '3.9', '135']
# ['178', 'JAGUAR', 'Vision II', 141.0, 73.8, 100.0, 'EDT', 'Men', {'fruity'}, {'cedar', 'wood', 'patchouli', 'musk'}, {'geranium', 'sea notes', 'pepper'}, 5.0, 'Parvant Store', '3.5', '76']
# ['179', 'Mariah Carey', 'Forever', 197.0, 126.0, 100.0, 'EDP', 'Women', {'floral'}, {'wood', 'musk'}, {'gardenia', 'tuberose'}, 4.0, 'perfumes--addresses', '4.4', '59']
# ['180', 'BURBERRY', 'Brit Splash', 278.0, 194.0, 100.0, 'EDT', 'Men', {'fresh'}, {'vetiver', 'moss', 'musk'}, {'water notes', 'cyclamen', 'violet'}, 4.6, 'Chansles', '3.9', '33']
# ['181', 'PRADA', 'Amber Intense', 324.0, 321.95, 100.0, 'EDP', 'Men', {'spicy'}, {'creamy amber'}, {'vanilla'}, 4.4, 'Ryhana Perfume', '4.2', '25']
# ['182', 'Milton Lloyd', 'Hawaii London', 51.0, 23.0, 55.0, 'EDT', 'Women', {'floral'}, {'notes', 'musk', 'woody'}, {'rose', 'jasmine'}, 4.0, 'hawas', '4.2', '9']
# ['183', 'Lattafa', 'Khalis Pure Oudi', 68.0, 37.0, 100.0, 'EDP', 'Unisex', {'woody'}, {'guaiac wood', 'amber', 'cedar', 'vanilla', 'musk'}, {'sandalwood', 'jasmine'}, 4.3, 'noon', '4.2', '98.1K']
# ['184', 'GUESS', 'Marciano', 111.0, 83.3, 100.0, 'EDP', 'Women', {'citrus'}, {'vanilla', 'accords', 'musk', 'woody'}, {'clean', 'intensively', 'peony', 'honeysuckle', 'jasmine', 'sweet', 'pink', 'rhythm', 'floral'}, 4.4, 'Star.perfume', '3.9', '537']
# ['185', 'DORALL COLLECTION', 'Oud Arabi', 11.35, 11.35, 100.0, 'PDT', 'Unisex', {'woody'}, {'patchouli', 'sandalwood', 'musk', 'amber'}, {'guaiac wood', 'rose', 'jasmine', 'oudh'}, 3.9, 'Princess of beauty', '3.8', '467']
# ['186', 'COACH', 'Coach', 36.0, 8.7, 2.0, 'EDP', 'Women', {'floral'}, {'cashmeran', 'suede', 'musk'}, {'gardenia', 'turkish rose'}, 4.8, 'top langri', '3.7', '347']
# ['187', 'Mancera', 'Coco Vanille', 446.0, 285.0, 120.0, 'EDP', 'Women', {'vanilla'}, {'woody notes', 'madagascar vanilla', 'white musk'}, {'ylangylang', 'jasmine', 'tiare flower'}, 5.0, 'AMLAQ', '3.9', '135']
# ['188', 'BURBERRY', 'Weekend', 197.0, 160.0, 100.0, 'EDP', 'Women', {'oriental'}, {'blue', 'iris', 'peach blossom', 'cyclamen', 'nectarine', 'rose', 'hip', 'violet root', 'red', 'hyacinth'}, {'blue hyacinth', 'iris', 'peach blossom', 'nectarine', 'rose hip red cyclamen', 'violet root'}, 4.6, 'AMLAQ', '3.9', '135']
# ['189', 'Estee Lauder', 'Private Collection', 461.0, 199.35, 50.0, 'EDP', 'Women', {'floral'}, {'sandalwood', 'amber', 'heliotrope', 'musk'}, {'coriander', 'reseda', 'ylangylang', 'chrysanthemum', 'bulgarian rose'}, 4.6, 'Rose Gallary', '3.9', '118']
# ['190', 'Marbert', 'Man Pure', 114.0, 54.7, 125.0, 'EDT', 'Men', {'citrus'}, {'amber', 'oak moss', 'cedar', 'sandalwood', 'musk'}, {'valley', 'coriander', 'the', 'jasmine', 'nutmeg', 'lily', 'majorjam', 'geranium'}, 4.9, 'Rayhanti', '3.8', '88']
# ['191', 'AMOUAGE', 'Gold', 1376.0, 904.85, 100.0, 'EDP', 'Women', {'woody'}, {'civet', 'sandalwood', 'ambergris', 'musk', 'cedar wood'}, {'myrrh', 'jasmine', 'orris'}, 4.4, 'Parvant Store', '3.8', '76']
# ['192', 'Givenchy', 'Gentlemen Only', 627.0, 260.0, 100.0, 'EDT', 'Men', {'woody'}, {'accord', 'bean', 'skin', 'tonka'}, {'patchouli', 'leather', 'heart', 'cedar wood'}, 4.0, 'Faces', '3.9', '61']
# ['193', 'JAGUAR', 'Classic Amber', 87.0, 85.0, 100.0, 'EDT', 'Men', {'arabian'}, {'labdanum', 'vetiver', 'vanilla', 'musk', 'cedar wood', 'patchouli', 'leather'}, {'orange', 'cinnamon', 'apple', 'elemi', 'resin', 'black pepper', 'blossoms'}, 4.3, 'Abu Al Tayyeb Perfumes', '3.9', '33']
# ['194', 'AIGNER', 'Debut', 220.0, 143.75, 100.0, 'EDP', 'Women', {'citrus'}, {'oak', 'white', 'cedar', 'vanilla', 'moss', 'musk', 'patchouli'}, {'water lily', 'jasmine', 'seed', 'luminous orange blossom', 'sunflower'}, 4.5, 'noon', '4.2', '98.1K']
# ['195', 'J.CASANOVA', 'Pandora', 142.0, 88.95, 100.0, 'EDP', 'Women', {'floral'}, {'amber', 'cedar', 'sandalwood', 'moss', 'musk'}, {'narcissus', 'rose', 'jasmine', 'orchid', 'lilyofthevalley'}, 5.0, 'noon', '4.2', '98.1K']
# ['196', 'Roberto Cavalli', 'Serpentine', 286.0, 162.85, 100.0, 'EDP', 'Women', {'arabian'}, {'sandalwood', 'tolu balsam', 'amber'}, {'pepper', 'violet leaf', 'tiare flower', 'frangipani'}, 4.4, 'noon', '4.2', '98.1K']
# ['197', 'BVLGARI', 'Man in Black', 483.0, 200.95, 100.0, 'EDP', 'Men', {'woody'}, {'beans', 'benzoin', 'wood', 'tonka', 'guaiac'}, {'leather', 'tuberose', 'iris'}, 4.7, 'Star.perfume', '3.9', '537']
# ['198', 'MONTBLANC', 'Lady Emblem', 8.5, 8.5, 2.0, 'EDT', 'Men', {'floral'}, {'patchouli', 'amber', 'vanilla', 'musk'}, {'geranium', 'jasmine', 'neroli', 'ylangylang'}, 5.0, 'Queen Beauty', '3.8', '467']
# ['199', 'Al Fakhr', 'Ameer Al Oud Khususi', 28.0, 12.0, 100.0, 'EDP', 'Unisex', {'woody'}, {'cedarwood', 'sandalwood'}, {'cardamom', 'black pepper'}, 4.1, 'kikup', '3.6', '425']
# ['200', 'LACOSTE', 'Touch Of Pink', 249.0, 90.0, 90.0, 'EDT', 'Women', {'floral'}, {'sandalwood', 'vanilla', 'musk'}, {'coriander', 'violet leaf', 'carrot seeds', 'jasmine', 'cardamom'}, 5.0, 'Cute Shop', '3.7', '347']
# ['201', 'Dior', 'Addict', 715.0, 333.8, 100.0, 'EDP', 'Women', {'floral'}, {'amber', 'caramel', 'pralines', 'sandalwood', 'vanilla'}, {'honeysuckle', 'jasmine', 'gardenia'}, 5.0, 'AMLAQ', '3.9', '135']
# ['202', 'BURBERRY', 'My Burberry Bl', 699.0, 255.85, 90.0, 'EDT', 'Women', {'floral'}, {'patchouli', 'amber'}, {'rose', 'peach', 'candied', 'nectar'}, 5.0, 'AMLAQ', '3.9', '135']
# ['203', 'joop', 'Homme', 170.0, 52.15, 75.0, 'EDT', 'Men', {'citrus'}, {'patchouli', 'sandalwood', 'tonka bean', 'vanilla'}, {'cinnamon', 'jasmine', 'cardamom', 'heliotrope', 'lilyofthevalley'}, 4.7, 'hadayiq baris', '3.8', '122']
# ['204', 'TED LAPIDUS', 'Creation', 101.0, 50.0, 100.0, 'EDT', 'Women', {'floral'}, {'rose', 'jasmine', 'carnation', 'tuberose'}, {'rose', 'jasmine', 'carnation', 'tuberose'}, 4.7, 'alkhalijiah  perfume', '3.5', '88']
# ['205', 'LOEWE', 'Esencia', 230.0, 219.9, 150.0, 'EDT', 'Men', {'woody'}, {'amber', 'fir', 'styrax', 'vetiver', 'cedar', 'sandalwood', 'musk', 'patchouli', 'leather', 'tonka bean', 'oakmoss'}, {'valley', 'clary sage', 'the', 'rose', 'jasmine', 'nutmeg', 'lily', 'pine tree needles', 'black currant', 'neroli', 'geranium', 'basil'}, 5.0, 'Y', '3.5', '75']
# ['206', 'Benetton', 'Hot', 124.0, 29.85, 100.0, 'EDT', 'Women', {'fruity'}, {'amber', 'oak', 'cedar', 'sandalwood', 'vanilla', 'moss', 'musk'}, {'valley', 'the', 'iris', 'jasmine', 'apricot', 'lily', 'water'}, 5.0, 'Beauty Gallery', '3.7', '59']
# ['207', 'KORLOFF', 'In White', 100.15, 100.15, 88.0, 'EDT', 'Men', {'citrus'}, {'cashmeran', 'virginia cedar', 'bean', 'musk', 'tonka'}, {'orange', 'flower', 'sage', 'clary', 'lavender', 'african'}, 4.8, 'noon', '4.2', '98.1K']
# ['208', 'LACOSTE', 'Lacoste', 310.0, 98.95, 50.0, 'EDP', 'Women', {'floral'}, {'incense', 'sandal', 'warm woman skin accord', 'himalayan cedar'}, {'blossom', 'rose', 'jasmine', 'alliance', 'hibiscus', 'heliotrope', 'in', 'bulgarian', 'an'}, 4.6, 'noon', '4.2', '98.1K']
# ['209', 'LACOSTE', 'Lacoste', 368.0, 115.0, 100.0, 'EDT', 'Men', {'citrus'}, {'amber', 'woody notes', 'cedar', 'vanilla', 'musk'}, {'almond', 'jasmine', 'ginger', 'black pepper'}, 4.6, 'noon', '4.2', '98.1K']
# ['210', 'Sedr Al-Khaleej Perfumes', 'Love Touch', 111.0, 49.85, 100.0, 'EDP', 'Women', {'fresh'}, {'musk', 'woody leather'}, {'rose', 'tiare flower'}, 5.0, 'noon', '4.2', '98.1K']
# ['211', 'BURBERRY', 'My Burberry Blush', 699.0, 199.9, 90.0, 'EDP', 'Women', {'arabian'}, {'wisteria', 'jasmine'}, {'apple', 'green', 'geranium', 'rose petals'}, 4.5, 'noon', '4.2', '98.1K']
# ['212', 'Lattafa', 'Rouat Al Oud', 144.0, 44.25, 100.0, 'EDP', 'Unisex', {'spicy'}, {'patchouli', 'cedarwood', 'vetiver', 'musk'}, {'cardamom', 'spicy', 'notes'}, 4.3, 'noon', '4.2', '98.1K']
# ['213', 'LANVIN', 'Rumeur', 154.0, 71.0, 100.0, 'EDP', 'Women', {'floral'}, {'patchouli', 'amber', 'musk'}, {'valley', 'the', 'rose', 'jasmine', 'plum', 'lily', 'orange blossom'}, 5.0, 'top langri', '3.7', '347']
# ['214', 'GUCCI', 'Oud', 690.0, 380.0, 75.0, 'EDP', 'Women', {'spicy'}, {'patchouli', 'oil', 'oud', 'natural'}, {'rose', 'bulgarian', 'orange', 'flower'}, 4.2, 'AMLAQ', '3.9', '135']
# ['215', 'CHLOE', 'Love Story', 383.0, 237.0, 50.0, 'EDP', 'Men', {'floral'}, {'amber', 'brazilian', 'vetiver', 'sandalwood', 'rosewood', 'musk'}, {'coriander', 'jasmine', 'sage', 'lily', 'geranium', 'orange blossom', 'lilyofthevalley', 'basil', 'juniper berries'}, 4.0, 'hadayiq baris', '3.8', '122']
# ['216', 'TED LAPIDUS', 'Rumba', 111.0, 58.0, 100.0, 'EDT', 'Women', {'floral'}, {'plum', 'styrax', 'leather tonka bean', 'cedar', 'sandalwood', 'vanilla', 'ambergris', 'musk', 'patchouli', 'oakmoss'}, {'valley', 'gardenia', 'the', 'rose', 'jasmine', 'carnation', 'orchid', 'honey', 'lily', 'marigold', 'magnolia', 'heliotrope', 'tuberose'}, 3.3, 'hadayiq baris', '3.8', '122']
# ['217', 'AMOUAGE', 'Honour', 1607.0, 710.95, 100.0, 'EDP', 'Women', {'spicy'}, {'cedar', 'vetiver', 'musk', 'patchouli', 'tonka bean', 'frankincense'}, {'geranium', 'elemi', 'nutmeg'}, 5.0, 'rich&light', '3.8', '66']
# ['218', 'Jimmy Choo', 'jimmy', 441.0, 188.95, 100.0, 'EDP', 'Women', {'floral'}, {'patchouli', 'coffee'}, {'orchid'}, 5.0, 'Faces', '3.9', '61']
# ['219', 'Rasasi', 'Blue', 53.0, 35.0, 100.0, 'EDT', 'Men', {'spicy'}, {'amber', 'woody'}, {'pepper', 'coriander', 'rose', 'jasmine', 'geranium'}, 4.3, 'hawas', '4.2', '9']
# ['220', 'Dunhill', 'Desire Silver', 192.0, 118.95, 100.0, 'EDT', 'Men', {'floral'}, {'birch', 'amber', 'vetiver'}, {'cardamom', 'water notes', 'violet leaf'}, 5.0, 'noon', '4.2', '98.1K']
# ['221', 'Calvin Klein', 'Euphoria Amber Gold', 327.0, 166.0, 100.0, 'EDP', 'Unisex', {'arabian'}, {'mint', 'moss', 'wood', 'lemon'}, {'cedar', 'sandalwood'}, 5.0, 'noon', '4.2', '98.1K']
# ['222', 'Britney Spears', 'Fantasy', 189.0, 89.95, 100.0, 'EDP', 'Women', {'floral'}, {'sensual woods', 'creamy musk', 'orris root'}, {'cupcakes', 'jasmine petals', 'white chocolate orchid'}, 5.0, 'noon', '4.2', '98.1K']
# ['223', 'GUCCI', 'Guilty Absolute', 515.0, 299.85, 90.0, 'EDP', 'Men', {'woody'}, {'vetiver', 'notes', 'woody'}, {'patchouli', 'cypress'}, 4.3, 'noon', '4.2', '98.1K']
# ['224', 'joop', 'Homme', 170.0, 57.0, 125.0, 'EDT', 'Men', {'citrus'}, {'patchouli', 'sandalwood', 'vanilla', 'tonka beans'}, {'valley', 'the', 'cinnamon', 'jasmine', 'cardamom', 'lily', 'heliotrope'}, 4.2, 'Cute Shop', '4.2', '98']
# ['225', 'Calvin Klein', 'Obsession', 231.0, 120.0, 125.0, 'EDT', 'Men', {'spicy'}, {'amber', 'sandalwood', 'vanilla', 'musk', 'patchouli'}, {'sage', 'pine', 'nutmeg', 'brazilian rosewood', 'myrrh', 'tree'}, 3.0, 'noon', '4.2', '98.1K']
# ['226', 'GUESS', 'Guess Pink', 105.0, 92.7, 75.0, 'EDP', 'Women', {'fruity'}, {'cedar', 'amber', 'oakmoss'}, {'valley', 'peach', 'peony', 'the', 'jasmine', 'lily', 'ylang', 'magnolia', 'freesia'}, 5.0, 'the beauty', '4.1', '538']
# ['227', 'Calvin Klein', 'One Shock', 383.0, 104.7, 200.0, 'EDT', 'Men', {'spicy'}, {'vetiver', 'sandalwood', 'amber'}, {'black basil', 'cardamom', 'osmanthus', 'black pepper'}, 5.0, 'AMLAQ', '3.9', '135']
# ['228', 'Lancome', 'Idol', 739.0, 299.0, 50.0, 'EDP', 'Women', {'floral'}, {'vanilla', 'white musk'}, {'de', 'mai', 'turkish rose', 'rose', 'jasmine', 'indian'}, 5.0, 'hadayiq baris', '3.8', '122']
# ['229', 'Dolce & Gabbana', 'The Only One 2', 614.0, 137.9, 100.0, 'EDP', 'Women', {'floral'}, {'patchouli', 'amber woods', 'ambergris', 'tonka'}, {'coffee', 'violet', 'red rose'}, 4.3, 'hadayiq baris', '3.8', '122']
# ...
# ['923', 'Lattafa', 'Oud Mood', 119.0, 42.55, 100.0, 'EDP', 'Unisex', {'woody'}, {'amber', 'incense', 'resin', 'musk', 'woody'}, {'patchouli', 'agarwood', 'caramel'}, 4.6, 'noon', '4.2', '98.1K']
# ['924', 'Roberto', 'Paradiso Assoluto', 515.0, 515.0, 75.0, 'EDP', 'Women', {'floral'}, {'patchouli', 'cashmeran', 'sandalwood', 'vanilla'}, {'red lily', 'passionfruit', 'wild jasmine'}, 4.5, 'garmid', '3.7', '98']
# ['925', 'Roberto Cavalli', 'Paradiso Assoluto', 515.0, 515.0, 75.0, 'EDP', 'Women', {'floral'}, {'patchouli', 'cashmeran', 'sandalwood', 'vanilla'}, {'red lily', 'passionfruit', 'wild jasmine'}, 5.0, 'garmid', '3.7', '98']
# ['926', 'GUCCI', 'Guilty Absolute', 515.0, 230.0, 90.0, 'EDP', 'Men', {'woody'}, {'vetiver', 'woody notes'}, {'patchouli', 'cypress'}, 4.1, 'Rayhanti', '3.5', '537']
# ['927', 'VERSACE', 'Bright Crystal', 430.0, 169.95, 90.0, 'EDT', 'Women', {'floral'}, {'amber', 'mahogany', 'musk'}, {'lotus', 'magnolia', 'peony'}, 4.8, 'noon', '4.2', '98.1K']
# ['928', 'Roberto Cavalli', 'Paradiso Azzuro', 499.0, 499.0, 75.0, 'EDP', 'Women', {'fruity'}, {'amberwood', 'sandalwood', 'cypress', 'cashmere wood'}, {'peach', 'apple', 'rose', 'wild jasmine', 'tuberose', 'watery notes'}, 4.7, 'garmid', '3.7', '135']
# ['929', 'Dunhill', 'Custom', 330.0, 89.85, 100.0, 'EDT', 'Men', {'floral'}, {'virginia cedar', 'incense'}, {'pepper'}, 4.3, 'noon', '4.2', '98.1K']
# ['930', 'Roberto Cavalli', 'Paradiso Azzurro', 499.0, 499.0, 75.0, 'EDP', 'Women', {'fruity'}, {'cashmere wood', 'cypress', 'sandalwood', 'vanilla', 'amber wood'}, {'peach', 'apple', 'rose', 'wild jasmine', 'tuberose', 'watery notes'}, 4.7, 'garmid', '3.7', '124']
# ['931', 'GUESS', 'Dare', 170.0, 75.0, 100.0, 'EDT', 'Women', {'citrus'}, {'wood', 'coconut accords', 'musk'}, {'elegant jasmine', 'wild rose'}, 4.9, 'noon', '3.7', '98.1K']
# ['932', 'DAVIDOFF', 'Hot Water', 215.0, 76.95, 110.0, 'EDT', 'Men', {'arabian'}, {'benzoin', 'styrax'}, {'patchouli', 'pimento'}, 4.6, 'AMLAQ', '3.9', '135']
# ['933', 'BURBERRY', 'For Women EDP Natural Sp', 378.0, 153.75, 100.0, 'EDP', 'Women', {'fruity'}, {'vanilla', 'musk'}, {'cedar', 'sandalwood', 'woodyfloral'}, 4.8, 'garmid', '3.7', '98']
# ['934', 'Dolce & Gabbana', 'K', 338.0, 269.0, 100.0, 'EDT', 'Men', {'woody'}, {'blood orange', 'sicilian', 'juniper', 'berries', 'pressed', 'lemon'}, {'geranium', 'pimento', 'lavandin', 'clary sage'}, 4.1, 'Grass gulf', '3.7', '98']
# ['935', 'JOVAN', 'Musk Cologne Sp', 55.0, 19.0, 59.0, 'EDT', 'Women', {'woody'}, {'amber', 'wood', 'musk'}, {'ylangylang'}, 4.7, 'garmid', '3.7', '1.9K']
# ['936', 'Dolce & Gabbana', 'K', 26.0, 14.1, 100.0, 'EDT', 'Men', {'aromatic'}, {'cedarwood', 'vetiver', 'patchouli accords', 'woody', 'masculine'}, {'geranium', 'pimento', 'lavandin', 'clary sage'}, 3.0, 'beautiful lady', '4.3', '5']
# ['937', 'LACOSTE', 'L.12.12 Blanc-Pure', 347.0, 94.2, 100.0, 'EDT', 'Men', {'woody'}, {'vetiver', 'leather', 'virginia cedar', 'suede'}, {'ylangylang', 'tuberose'}, 4.6, 'garmid', '3.7', '98']
# ['938', 'TED LAPIDUS', 'Pour Homme', 129.0, 44.45, 100.0, 'EDT', 'Men', {'woody'}, {'tobacco', 'amber', 'cedar', 'sandalwood', 'musk', 'patchouli', 'tonka bean', 'oakmoss'}, {'pine tree', 'incense', 'rose', 'jasmine', 'brazilian rosewood', 'honey', 'orris root', 'petitgrain', 'lilyofthevalley', 'caraway'}, 5.0, 'neo lek', '3.6', '88']
# ['939', 'HUGO BOSS', 'Bottled Unlimited', 373.0, 126.0, 100.0, 'EDT', 'Men', {'vanilla'}, {'sandalwood', 'musk'}, {'rose', 'pineapple'}, 4.4, 'Al-Najm', '3.7', '347']
# ['940', 'GIORGIO ARMANI', 'Stronger With You', 415.0, 170.0, 100.0, 'EDT', 'Men', {'vanilla'}, {'guaiac wood', 'chestnut', 'cedar', 'vanilla', 'amber wood'}, {'cinnamon', 'sage', 'melon', 'pineapple', 'lavender'}, 4.5, 'hadayiq baris', '3.8', '122']
# ['941', 'HUGO BOSS', 'Ma Vie', 415.0, 137.55, 75.0, 'EDP', 'Women', {'floral'}, {'cedar', 'notes', 'woody'}, {'rose', 'jasmine', 'pink freesia'}, 4.7, 'AMLAQ', '3.9', '135']
# ['942', 'DORALL COLLECTION', 'Pink Hearts', 29.0, 8.15, 100.0, 'EDT', 'Women', {'floral'}, {'caramel', 'sandalwood', 'vanilla', 'musk', 'tonka'}, {'valley', 'licorice', 'candy', 'the', 'red berries', 'lily', 'cotton', 'strawberry'}, 4.4, 'B.A.G', '3.7', '14.1K']
# ['943', 'Givenchy', 'Xeryus Rouge', 455.0, 214.4, 100.0, 'EDT', 'Men', {'woody'}, {'cedar wood'}, {'red pepper'}, 4.8, 'noon', '4.2', '98.1K']
# ['944', 'Dolce & Gabbana', 'The Only One 2', 614.0, 137.9, 100.0, 'EDP', 'Women', {'floral'}, {'patchouli', 'amber woods', 'ambergris', 'tonka'}, {'coffee', 'violet', 'red rose'}, 4.3, 'hadayiq baris', '3.8', '122']
# ['945', 'TESORI D´ORIENTE', 'White Musk', 60.0, 39.95, 100.0, 'EDT', 'Men', {'woody'}, {'jasmine', 'aldehyde', 'white flowers'}, {'rose'}, 4.2, 'B.A.G', '3.7', '14.1K']
# ['946', 'Mancera', 'Roses Vanille', 446.0, 248.8, 120.0, 'EDP', 'Women', {'arabian'}, {'cedar', 'vanilla', 'white musk', 'sugar'}, {'rose', 'sugar'}, 5.0, 'noon', '4.2', '98.1K']
# ['947', 'BURBERRY', 'My Blush', 431.0, 181.0, 50.0, 'EDP', 'Women', {'arabian'}, {'wisteria', 'jasmine'}, {'apple', 'green', 'geranium', 'rose petals'}, 4.6, 'Fnoon', '3.7', '5']
# ['948', 'BURBERRY', 'My Burberry Blush', 699.0, 199.9, 90.0, 'EDP', 'Women', {'arabian'}, {'wisteria', 'jasmine'}, {'apple', 'green', 'geranium', 'rose petals'}, 4.5, 'noon', '4.2', '98.1K']
# ['949', 'Guerlain', "L'Instant Magic", 725.0, 422.0, 100.0, 'EDP', 'Women', {'woody'}, {'almond', 'wood'}, {'rose', 'freesia'}, 4.7, 'PARFUM.1990', '4.1', '33']
# ['950', 'Dunhill', 'London', 290.0, 109.65, 75.0, 'EDT', 'Men', {'arabian'}, {'sandalwood', 'vanilla', 'musk', 'patchouli', 'tonka bean'}, {'geranium', 'rose', 'jasmine'}, 3.4, 'AMLAQ', '3.9', '135']
# ['951', 'BURBERRY', 'Body Mini ED', 34.0, 23.0, 5.0, 'EDT', 'Women', {'woody'}, {'amber', 'cashmerean', 'sandalwood', 'vanilla', 'musk'}, {'rose', 'iris'}, 1.0, 'Royal Scent', '3.5', '5']
# ['952', 'TRI', 'En Joy', 10.0, 9.9, 100.0, 'EDT', 'Women', {'floral'}, {'cedar', 'benzoin', 'sandalwood', 'musk', 'patchoulli'}, {'rose', 'jasmine', 'cassis', 'peach'}, 4.1, 'Parisian Store', '4.1', '425']
# ['953', 'Mancera', 'Rose Greedy', 446.0, 269.0, 120.0, 'EDP', 'Unisex', {'floral'}, {'amber', 'vanilla', 'white musk', 'sugar'}, {'rose', 'jasmine', 'flowers'}, 4.5, 'AMLAQ', '3.9', '135']
# ['954', 'DORALL COLLECTION', 'Oud Maaruf', 29.0, 11.49, 100.0, 'EDT', 'Men', {'arabian'}, {'amber', 'woody  amber', 'sandalwood', 'dry woodyamber', 'musk', 'oudh', 'patchouli'}, {'orris', 'raspberry', 'rose', 'dried fruits', 'saffron', 'muguet', 'ylang', 'geranium', 'jasmin'}, 4.0, 'B.A.G', '3.7', '14.1K']
# ['955', 'BURBERRY', 'Burberry Body Intense', 435.0, 152.45, 60.0, 'EDP', 'Women', {'fruity'}, {'amber', 'cashmere wood', 'vanille', 'musk'}, {'sandalwood', 'rose', 'iris'}, 4.6, 'noon', '4.2', '98.1K']
# ['956', 'Mancera', 'Roses Vanille', 450.0, 285.0, 120.0, 'EDP', 'Women', {'arabian'}, {'cedar', 'vanilla', 'white musk', 'sugar'}, {'rose', 'sugar'}, 4.9, 'AMLAQ', '3.9', '135']
# ['957', 'Mancera', 'Roses Vanille', 450.0, 239.95, 120.0, 'EDP', 'Women', {'arabian'}, {'cedar', 'vanilla', 'white musk', 'sugar'}, {'rose', 'sugar'}, 4.7, 'noon', '4.2', '98.1K']
# ['958', 'Dunhill', 'Desire', 276.0, 84.25, 100.0, 'EDT', 'Men', {'fresh'}, {'vanilla', 'musk'}, {'patchouli', 'rose', 'teak wood'}, 4.5, 'S2021', '3.5', '23']
# ['959', 'Parfums Gres', 'Cabotine', 135.0, 75.0, 100.0, 'EDT', 'Women', {'floral'}, {'cedarwood', 'amber', 'cybet', 'vanilla', 'musk', 'tonka bean'}, {'iris', 'rose', 'ylangylang', 'tuberose', 'heliotrope', 'violet', 'ginger lily', 'freesia', 'hyacinth'}, 4.8, 'AMLAQ', '3.9', '135']
# ['960', 'Alina Corel', 'Monsieur Oud', 51.0, 30.95, 100.0, 'EDP', 'Unisex', {'musk'}, {'cedar', 'musk'}, {'rose', 'water'}, 4.5, 'noon', '4.2', '98.1K']
# ['961', 'GIORGIO ARMANI', 'Si Passione EDP For Wo', 630.0, 235.45, 100.0, 'EDP', 'Women', {'floral'}, {'cedar', 'patchouli', 'vanilla'}, {'rose', 'jasmine', 'heliotrope', 'pineapple'}, 5.0, 'Parfume-Stor', '4.1', '347']
# ['962', 'Yves Saint Laurent', 'Kouros Silver', 540.0, 190.0, 100.0, 'EDT', 'Men', {'fruity'}, {'amber', 'notes', 'woody'}, {'sage'}, 4.5, 'Queen Beauty', '3.5', '5']
# ['963', 'Dior', 'Sauvage Perf', 640.0, 326.4, 100.0, 'EDT', 'Men', {'floral'}, {'tonka bean', 'vanilla', 'olibanum'}, {'sandalwood'}, 3.0, 'Parfume-Stor', '4.1', '75']
# ['964', 'DAVIDOFF', 'Cool Water', 150.0, 71.75, 75.0, 'EDT', 'Men', {'aromatic'}, {'cedar', 'amber', 'musk', 'oakmoss'}, {'geranium', 'sandalwood', 'jasmine', 'neroli'}, 4.1, 'noon', '4.2', '98.1K']
# ['965', 'DAVIDOFF', 'Cool Water', 315.0, 85.5, 125.0, 'EDT', 'Men', {'fresh'}, {'tobacco', 'amber', 'cedar', 'musk', 'oakmoss'}, {'geranium', 'sandalwood', 'jasmine', 'neroli'}, 3.7, 'Lolita Shop', '3.6', '5']
# ['966', 'BVLGARI', 'Aqva Marine Pour Homme', 331.0, 163.95, 100.0, 'EDT', 'Men', {'citrus'}, {'virginia cedar', 'amber'}, {'water notes', 'rosemary', 'seaweed'}, 4.8, 'hadayiq baris', '3.8', '122']
# ['967', 'Dior', 'Sauvage', 430.0, 208.25, 100.0, 'EDT', 'Men', {'spicy'}, {'cedar', 'labdanum', 'ambroxan'}, {'patchouli', 'elemi', 'pink pepper', 'lavender', 'vetiver', 'geranium', 'sichuan pepper'}, 4.6, 'Spicebomb', '3.5', '66']
# ['968', 'GUESS', 'Marciano', 150.0, 80.7, 100.0, 'EDT', 'Men', {'spicy'}, {'spicy', 'woody'}, {'lavenday', 'spicy', 'sage'}, 4.7, 'AMLAQ', '3.9', '135']
# ['969', 'GIORGIO ARMANI', 'Armani Code', 514.0, 280.1, 125.0, 'EDT', 'Men', {'citrus'}, {'leather', 'bean', 'tobacco', 'tonka'}, {'blossom', 'olive', 'star anise', 'wood', 'guaiac'}, 2.0, 'noon', '4.2', '98.1K']
# ['970', 'CAROLINA HERRERA', '212 Sexy', 330.0, 104.5, 100.0, 'EDT', 'Men', {'vanilla'}, {'amber', 'sandalwood', 'bourbon vanilla', 'musk', 'sensual oriental character  gaiac wood'}, {'pepper', 'sensuality', 'tonka beans', 'green', 'subtle', 'cardamom', 'spicy', 'floral petal'}, 4.2, 'Al-Najm', '3.7', '347']
# ['971', 'BVLGARI', 'Petits Et Mamans', 254.0, 193.95, 100.0, 'EDT', 'Women', {'floral'}, {'powdery notes', 'white peach', 'vanilla', 'iris'}, {'sunflower', 'rose', 'chamomile'}, 4.8, 'noon', '4.2', '98.1K']
# ['972', 'Justcavalli', 'Just Cavalli', 385.0, 131.4, 75.0, 'EDT', 'Women', {'floral'}, {'creamy', 'rosewood', 'cuddly'}, {'tahitian tiare flowers'}, 4.6, 'Star.perfume', '3.9', '537']
# ['973', 'Jean Paul GAULTIER', 'Scandal', 505.0, 354.95, 80.0, 'EDP', 'Women', {'floral'}, {'labdanum', 'vanilla', 'musk'}, {'blossom', 'jasmine', 'tiare flower', 'orange'}, 4.5, 'noon', '4.2', '98.1K']
# ['974', 'GUCCI', 'Bloom Aqua Di Fiori', 515.0, 311.8, 100.0, 'EDT', 'Women', {'fruity'}, {'jasmine'}, {'tuberose'}, 4.7, 'noon', '4.2', '98.1K']
# ['975', 'GUCCI', 'Bloom', 695.0, 325.65, 100.0, 'EDP', 'Women', {'floral'}, {'rangoon creeper'}, {'tuberose'}, 4.6, 'noon', '4.2', '98.1K']
# ['976', 'VERSACE', 'Crystal Noir', 447.0, 172.0, 90.0, 'EDP', 'Women', {'oriental'}, {'pod', 'cashmeran', 'sandalwood', 'vanilla', 'heliotropine'}, {'jasmine', 'dry', 'tuberose', 'frangipani'}, 4.4, 'flower', '3.7', '98']
# ['977', 'GUCCI', 'Bloom Nettare Di Fiori', 630.0, 329.85, 100.0, 'EDP', 'Women', {'floral'}, {'schijnhulst', 'patchoulie', 'musk'}, {'honeysuckle', 'jasmine', 'tuberose'}, 4.3, 'noon', '4.2', '98.1K']
# ['978', 'Givenchy', "L'interdit", 680.0, 195.5, 80.0, 'EDP', 'Women', {'floral'}, {'patchouli', 'vetiver'}, {'blossom', 'jasmine', 'orange', 'tuberose'}, 2.3, 'Pinch Of Perfum', '3.5', '347']
# ['979', 'CAROLINA HERRERA', 'Good Girl', 565.0, 168.0, 80.0, 'EDP', 'Women', {'arabian'}, {'tonka bean', 'cocoa'}, {'tuberose', 'jasmine sambac'}, 4.1, 'hadayiq baris', '3.8', '122']
# ['980', 'Genie Collection', 'Premium', 35.0, 14.5, 25.0, 'EDP', 'Unisex', {'oriental'}, {'patchouli', 'amber', 'musk'}, {'ylangylang', 'jasmine', 'tuberose'}, 5.0, 'Genie collection', '3.7', '32']
# ['981', 'Rasasi', 'Oud Al-Mubakhar', 40.0, 30.85, 100.0, 'EDP', 'Men', {'arabian'}, {'patchouli', 'sandalwood', 'tonka bean', 'musk'}, {'geranium', 'violet', 'turkish rose'}, 4.0, 'noon', '4.2', '98.1K']
# ['982', 'Roberto Cavalli', 'Nero Assoluto', 264.0, 129.55, 75.0, 'EDP', 'Women', {'arabian'}, {'woodsy notes', 'ebony'}, {'vanilla'}, 5.0, 'noon', '4.2', '98.1K']
# ['983', 'Roberto Cavalli', 'Nero Assoluto', 515.0, 105.0, 75.0, 'EDP', 'Women', {'arabian'}, {'woody notes', 'ebony'}, {'vanilla'}, 4.6, 'noon', '4.2', '98.1K']
# ['984', 'GUESS', 'Homme', 210.0, 98.0, 100.0, 'EDT', 'Men', {'spicy'}, {'patchouli', 'sandalwood', 'musk', 'amber'}, {'vetiver', 'leaves', 'violet', 'vanilla orchid'}, 4.4, 'Star.perfume', '3.9', '537']
# ['985', 'Lattafa', 'Ana Abiyedh Leather', 65.0, 47.9, 60.0, 'EDP', 'Men', {'musk'}, {'guaiac wood', 'tonka bean'}, {'cardamom', 'saffron', 'vanilla'}, 4.6, 'top langri', '4.3', '347']
# ['986', 'Roberto Cavalli', 'Just Cavalli', 357.0, 101.95, 90.0, 'EDT', 'Men', {'woody'}, {'leather'}, {'vetiver'}, 4.8, 'noon', '4.2', '98.1K']
# ['987', 'HUGO BOSS', 'Bottled Night', 688.0, 250.0, 200.0, 'EDT', 'Men', {'woody'}, {'woody notes', 'musk'}, {'violet'}, 4.5, 'Lady Style', '3.6', '5']
# ['988', 'MONTBLANC', 'Emblem', 363.0, 146.6, 100.0, 'EDT', 'Men', {'spicy'}, {'tonka bean', 'notes', 'woody'}, {'leaf', 'violet', 'cinnamon'}, 4.4, 'noon', '4.2', '98.1K']
# ['989', 'MONTBLANC', 'Emblem', 363.0, 146.55, 100.0, 'EDT', 'Men', {'spicy'}, {'woody notes', 'tonka bean'}, {'violet leaf', 'cinnamon'}, 5.0, 'noon', '4.2', '98.1K']
# ['990', 'HUGO BOSS', 'Nuit', 415.0, 162.0, 75.0, 'EDP', 'Women', {'floral'}, {'woods', 'sandalwood', 'moss', 'warm', 'crystal'}, {'white', 'florals', 'jasmin', 'violet'}, 4.8, 'AMLAQ', '3.9', '135']
# ['991', 'Elizabeth Taylor', 'White Diamonds', 220.0, 118.85, 100.0, 'EDT', 'Women', {'floral'}, {'amber', 'oak moss', 'sandalwood', 'musk', 'patchouli'}, {'', 'rose', 'jasmine', 'ylangylang', 'violet'}, 4.3, 'noon', '4.2', '98.1K']
# ['992', 'Marc Jacobs', 'Daisy Eau So Fresh', 330.0, 179.4, 125.0, 'EDT', 'Women', {'fruity'}, {'cedarwood', 'plum', 'musk'}, {'wild rose', 'lychee', 'jasmine petals', 'violet', 'apple blossom'}, 5.0, 'noon', '4.2', '98.1K']
# ['993', 'CARTIER', 'Pasha Edition Noir', 478.0, 198.55, 100.0, 'EDT', 'Men', {'oriental'}, {'cedar', 'amber', 'accords', 'woody'}, {'warm', 'aromas', 'cuddly'}, 4.6, 'AMLAQ', '3.9', '135']
# ['994', 'MONTBLANC', 'Legend Spirit', 342.0, 140.0, 100.0, 'EDT', 'Men', {'citrus'}, {'white woods', 'oakmoss', 'white musk', 'cashmere wood'}, {'cardamom', 'water notes', 'lavender'}, 4.7, 'hadayiq baris', '3.8', '122']
# ['995', 'BVLGARI', 'Petits Et Mamans', 327.0, 197.75, 100.0, 'EDT', 'Women', {'floral'}, {'vanilla', 'iris'}, {'white peach'}, 4.8, 'Tiffany', '4.1', '75']
# ['996', 'Roberto Cavalli', 'Paradiso Assoluto', 515.0, 139.0, 75.0, 'EDP', 'Women', {'floral'}, {'patchouli', 'cashmeran', 'sandalwood', 'vanilla'}, {'red lily', 'passionfruit', 'wild jasmine'}, 5.0, 'noon', '4.2', '98.1K']
# ['997', 'Roberto Cavalli', 'Paradiso Azzurro', 499.0, 165.0, 75.0, 'EDP', 'Women', {'fruity'}, {'cashmere wood', 'cypress', 'sandalwood', 'vanilla', 'amber wood'}, {'peach', 'apple', 'rose', 'wild jasmine', 'tuberose', 'watery notes'}, 4.7, 'Beauty Group', '4.3', '124']
# ['998', 'GUESS', 'Dare', 170.0, 75.0, 100.0, 'EDT', 'Women', {'citrus'}, {'wood', 'coconut accords', 'musk'}, {'elegant jasmine', 'wild rose'}, 4.9, 'noon', '4.2', '98.1K']
# ['999', 'BURBERRY', 'For Women EDP Natural Sp', 378.0, 153.75, 100.0, 'EDT', 'Women', {'fruity'}, {'vanilla', 'musk'}, {'cedar', 'sandalwood', 'woodyfloral'}, 4.8, 'noon', '4.2', '98.1K']
# ['1000', 'JOVAN', 'Musk Cologne Sp', 55.0, 19.0, 59.0, 'EDT', 'Women', {'woody'}, {'amber', 'wood', 'musk'}, {'ylangylang'}, 4.7, 'Cute', '3.7', '1.9K']
# ['1001', 'SWISS ARABIAN', 'Layali CPO At', 126.0, 77.0, 15.0, 'EDT', 'Unisex', {'arabian'}, {'amber', 'agarwood'}, {'ylangylang', 'rose', 'jasmine'}, 4.0, 'Swiss Arabian PerfumesPRICE UPDATE WITH 15% VAT 1 JULY 2020', '3.9', '5']
# ['1002', 'LACOSTE', 'L.12.12 Blanc-Pure', 347.0, 94.2, 100.0, 'EDT', 'Men', {'woody'}, {'vetiver', 'leather', 'virginia cedar', 'suede'}, {'ylangylang', 'tuberose'}, 4.6, 'noon', '4.2', '98.1K', '']

# %%
text = ''
for perfume in sorted(perfumes, key=lambda x: int(x[0])):
    temp = '['
    for item in perfume:
        temp += "'"
        temp += str(item)
        temp += "'"
        temp += '@'
    text += temp 
    text += ']'
    text += '_'
with open('Purified_dataset5' + '.txt', 'w') as f:
    f.write(text[:-2])

# %%
## 01. 파일 읽기
perfumes_dataset = open("/content/noon_perfumes_dataset.csv")
perfumes_dataset = perfumes_dataset.read()
perfumes_dataset = perfumes_dataset.replace('\n', ',').split(',')
perfumes = [] 
perfumes_tag = perfumes_dataset[:15]
perfumes_data = perfumes_dataset[15:]


## 02. 향수 별로 구분하기 ...  perfumes : [ [향수1], [향수2], ....]
idx = '1'
perfume_now = []
for data in perfumes_data:
    if data == idx:
        idx = str(int(idx) + 1)
        perfumes.append(perfume_now)
        perfume_now = []
    perfume_now.append(data)
perfumes.append(perfume_now)


## 03. 향수 내 대분류 정리
for perfume in perfumes:
    ## 03-1. old_price / new_price / ml -->> str2float
    perfume[3], perfume[4], perfume[5] = float(perfume[3]), float(perfume[4]), float(perfume[5])

    ## 03-2. scents - col no. 8
    perfume = Category_binder(perfume, 8)

    ## 03-3. base_note - col no. 9
    perfume = Category_binder(perfume, 9)

    ## 03-4. middle_note - col no. 10
    perfume = Category_binder(perfume, 10)

    ## 03-5. item_rating -->> str2float
    perfume[11] = float(perfume[11])


## 04. 향수 데이터 형식
# 0.no, 1.brand, 2.name, 3.old_price, 4.new_price, 5.mL, 6.Time_category, 7.gender, 8.Top, 9.base, 10.middle, 11.rating
all_brands = set()              # 01    150
all_names = set()               # 02    589
brand_plus_name = set()        #################
all_concentrations = set()      # 06    5
all_departments = set()         # 07    4
all_scents = set()              # 08    18
all_bases = set()               # 09    426
all_middles = set()             # 10    606

for perfume in perfumes:
    all_brands.add(perfume[1].lower())
    all_names.add(perfume[2].lower())
    brand_plus_name.add((perfume[1].lower(), perfume[2].lower()))
    all_concentrations.add(perfume[6].lower())
    all_departments.add(perfume[7].lower())
    for pt in perfume[8]:
        all_scents.add(pt.lower())
    for pb in perfume[9]:
        all_bases.add(pb.lower())
    for pm in perfume[10]:
        all_middles.add(pm.lower())

# %%
scents = sorted(list(all_scents))
notes = sorted(list(all_middles | all_bases))[5:]

# %% [markdown]
# # ** 1.05. Check

# %%
### ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Top_scents 하나 당 포함하는 notes 종류
# 0.no, 1.brand, 2.name, 3.old_price, 4.new_price, 5.mL, 6.Time_category, 7.gender, 8.Top, 9.base, 10.middle, 11.rating
scents2notes = {}
for top in all_scents:
    scents2notes[top] = [set(), set(), set()]
    for perfume in perfumes:
        if top in perfume[8]:
            for pm in perfume[10]:
                scents2notes[top][0].add(pm)
            for pb in perfume[9]:
                scents2notes[top][1].add(pb)
            scents2notes[top][2] = scents2notes[top][0] | scents2notes[top][1]
    # print(top, scents2notes[top])
    # >>> floral [{'', 'hibiscus seed', 'coriander', 'pearlescent', 'dewy english roses',.......}]

# %%
### ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Top_scent 1 개에 포함되어 있는 notes 전체
top2notes_cnt = {}
all_notes = {}
for scent in scents:
    temp = {}
    for perfume in perfumes:
        if scent in perfume[8]:
            now_all = perfume[10] | perfume[9]
            for now in now_all:
                if now == 'lilyofthevalley':
                    now = 'lily of the valley'
                if now in temp:
                    temp[now] += 1
                else:
                    temp[now] = 1
                if now in all_notes:
                    all_notes[now] += 1
                else:
                    all_notes[now] = 1
    top2notes_cnt[scent] = sorted(temp.items(), key=lambda x: x[1], reverse=True)

# for scent in scents:
#     print(scent, len(top2notes_cnt[scent]), top2notes_cnt[scent])
# >>> arabian 176 [('vanilla', 28), ('musk', 25), ('amber', 23), ('sandalwood', 22), ('tonka bean', 22), ('patchouli', 21), ....

# %%
## 향수별로 얼마나 notes 들이 많이 사용되었는지,
## 빈도 그래프를 출력한다

all_notes = sorted(all_notes.items(), key=lambda x: x[1], reverse=True)
# all_notes
# >>> [('musk', 412), ('jasmine', 353), ('sandalwood', 349), ('amber', 340), ....

# len(all_notes)
# >>> 861


import matplotlib.pyplot as plt
import numpy as np

x_labels = []
y_labels = []
x = np.arange(len(all_notes))
for top in all_notes:
    x_labels.append(top[0])
    y_labels.append(top[1])

plt.bar(x, y_labels)
plt.xticks(x, x_labels)
plt.show()

# %%
## Scents 2 Notes Graph ~ sorted

# import matplotlib.pyplot as plt
# import numpy as np

# for scent in scents:
#     x = np.arange(len(puri_cutter[scent]))
#     Notes = []
#     Count = []
#     for it in puri_cutter[scent]:
#         Notes.append(it[0])
#         Count.append(it[1])

#     plt.bar(x, Count)
#     plt.xticks(x, Notes)

#     print(scent, len(puri_cutter[scent]), puri_cutter[scent])
#     plt.show()

# %% [markdown]
# # ** 2. Data purification

# %%
## 안 쓰이는 notes 들 제거하기
puri_notes = []
for top in all_notes:
    note, cnt = top
    if cnt >= 10:
        puri_notes.append(note)

# %%
## Sparse 2 Densee
puri_notes = set()
puri_cutter =top2notes_cnt
for top in puri_cutter:
    temp = []
    for sc, cnt in puri_cutter[top]:
        if cnt >= 3:
            puri_notes.add(sc)
            temp.append((sc, cnt))
    puri_cutter[top] = temp

# for scent in scents:
#     print(scent, len(puri_cutter[scent]), puri_cutter[scent])
# >>> arabian 51 [('vanilla', 28), ('musk', 25), ('amber', 23), ('sandalwood', 22), ...


puri_notes = sorted(list(puri_notes)[:-1])
# print(len(puri_notes))
# puri_notes
# >>> 240
# >>> ['accord', 'accords', 'african orange flower', 'agarwood', 'almond',...

# %%
### !!!! 실제 데이터 구성 !!! ###
## 현재 - puri_notes(240) @ scents(11)
Data_x = [[0.01] * len(puri_notes) for _ in range(len(perfumes))]
Data_y = [[0] * len(scents) for _ in range(len(perfumes))]
for i in range(len(perfumes)):
    perfume = perfumes[i]
    data_x = list(perfume[10] | perfume[9])
    data_y = list(perfume[8])[0]
    for data in data_x:
        if data not in puri_notes:
            continue
        Data_x[i][puri_notes.index(data)] = 1.00
    Data_y[i][scents.index(data_y)] = 1

# %%
### !!!! 실제 데이터 구성 !!! ###
x_all = np.array(Data_x)
y_all = np.array(Data_y)
# x_train, x_test = x_all[:800], x_all[801:]
# y_train, y_test = y_all[:800], y_all[801:]

# print(x_train.shape)
# print(y_train.shape)
print(x_all.shape)
print(y_all.shape)
# Out:
# (1003, 240)
# (1003, 11)

# %% [markdown]
# # ** 3. Classification model **

# %%
from tensorflow import keras
from keras.layers import Dense, Conv2D, MaxPooling1D

c_model = keras.Sequential()

c_model.add(Dense(128, activation='relu'))
c_model.add(Dense(64, activation='relu'))
c_model.add(Dense(11, activation='softmax'))

# %%
c_model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# history = c_model.fit(x_train, y_train, epochs=20, validation_split=0.2, batch_size=10)
history = c_model.fit(x_all, y_all, epochs=20, batch_size=20, shuffle=True, validation_split=0.2)
# Out:
# Epoch 1/20
# 41/41 [==============================] - 1s 9ms/step - loss: 2.1306 - accuracy: 0.2943 - val_loss: 2.0619 - val_accuracy: 0.2985
# Epoch 2/20
# 41/41 [==============================] - 0s 4ms/step - loss: 1.8731 - accuracy: 0.3828 - val_loss: 1.9425 - val_accuracy: 0.3532
# Epoch 3/20
# 41/41 [==============================] - 0s 4ms/step - loss: 1.7140 - accuracy: 0.4464 - val_loss: 1.8634 - val_accuracy: 0.3881
# Epoch 4/20
# 41/41 [==============================] - 0s 3ms/step - loss: 1.5640 - accuracy: 0.5000 - val_loss: 1.8013 - val_accuracy: 0.4279
# Epoch 5/20
# 41/41 [==============================] - 0s 3ms/step - loss: 1.4231 - accuracy: 0.5449 - val_loss: 1.7121 - val_accuracy: 0.4478
# Epoch 6/20
# 41/41 [==============================] - 0s 3ms/step - loss: 1.2769 - accuracy: 0.6110 - val_loss: 1.6914 - val_accuracy: 0.4826
# Epoch 7/20
# 41/41 [==============================] - 0s 3ms/step - loss: 1.1453 - accuracy: 0.6309 - val_loss: 1.6502 - val_accuracy: 0.5124
# Epoch 8/20
# 41/41 [==============================] - 0s 3ms/step - loss: 1.0217 - accuracy: 0.6983 - val_loss: 1.6484 - val_accuracy: 0.4975
# Epoch 9/20
# 41/41 [==============================] - 0s 4ms/step - loss: 0.9163 - accuracy: 0.7294 - val_loss: 1.6444 - val_accuracy: 0.5423
# Epoch 10/20
# 41/41 [==============================] - 0s 3ms/step - loss: 0.8159 - accuracy: 0.7519 - val_loss: 1.6265 - val_accuracy: 0.5423
# Epoch 11/20
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7325 - accuracy: 0.7756 - val_loss: 1.7089 - val_accuracy: 0.5174
# Epoch 12/20
# 41/41 [==============================] - 0s 3ms/step - loss: 0.6547 - accuracy: 0.8130 - val_loss: 1.7174 - val_accuracy: 0.5423
# Epoch 13/20
# 41/41 [==============================] - 0s 3ms/step - loss: 0.5876 - accuracy: 0.8342 - val_loss: 1.8058 - val_accuracy: 0.5025
# Epoch 14/20
# 41/41 [==============================] - 0s 3ms/step - loss: 0.5413 - accuracy: 0.8479 - val_loss: 1.7917 - val_accuracy: 0.5224
# Epoch 15/20
# 41/41 [==============================] - 0s 3ms/step - loss: 0.4823 - accuracy: 0.8591 - val_loss: 1.8579 - val_accuracy: 0.5572
# Epoch 16/20
# 41/41 [==============================] - 0s 3ms/step - loss: 0.4404 - accuracy: 0.8616 - val_loss: 1.9328 - val_accuracy: 0.5224
# Epoch 17/20
# 41/41 [==============================] - 0s 3ms/step - loss: 0.3968 - accuracy: 0.8890 - val_loss: 1.9327 - val_accuracy: 0.5572
# Epoch 18/20
# 41/41 [==============================] - 0s 3ms/step - loss: 0.3619 - accuracy: 0.8890 - val_loss: 1.9801 - val_accuracy: 0.5224
# Epoch 19/20
# 41/41 [==============================] - 0s 3ms/step - loss: 0.3341 - accuracy: 0.9052 - val_loss: 2.0435 - val_accuracy: 0.5373
# Epoch 20/20
# 41/41 [==============================] - 0s 3ms/step - loss: 0.3160 - accuracy: 0.9115 - val_loss: 2.0845 - val_accuracy: 0.5274

# %%
# loss_test, acc_test = c_model.evaluate(x_test, y_test)
loss_test, acc_test = c_model.evaluate(x_all, y_all)

print(loss_test)
print(acc_test)
# Out:
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6386 - accuracy: 0.8504
# 0.638617217540741
# 0.8504486680030823

# %%
keras.utils.plot_model(c_model, show_shapes=True)

# %%
c_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               30848
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 11)                715
#
# =================================================================
# Total params: 39,819
# Trainable params: 39,819
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 10. 학습 시각화하기
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc = 'upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc = 'upper left')
plt.show()

# %% [markdown]
# # ** 4. Auto-Encoder model **

# %%
import keras
from keras import layers
input_dim = 240

# This is the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# This is our input image
input_img = keras.Input(shape=(input_dim,))
# "encoded" is the encoded representation of the input
encoded = layers.Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = layers.Dense(input_dim, activation='sigmoid')(encoded)

# This model maps an input to its reconstruction
autoencoder = keras.Model(input_img, decoded)

# %%
# This model maps an input to its encoded representation
encoder = keras.Model(input_img, encoded)

# %%
# This is our encoded (32-dimensional) input
encoded_input = keras.Input(shape=(encoding_dim,))
# Retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# Create the decoder model
decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# from keras.datasets import mnist
# import numpy as np
# (x_train, _), (x_test, _) = mnist.load_data()

# %%
# x_train = x_train.astype('float32') / 255.
# x_test = x_test.astype('float32') / 255.
# x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
# x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
# print(x_train.shape)
# print(x_test.shape)

# %%
print(x_all.shape)
print(y_all.shape)
# Out:
# (1003, 240)
# (1003, 11)

# %%
history = autoencoder.fit(x_all, x_all,
                epochs=100,
                batch_size=20,
                shuffle=True,
                validation_split=0.2)
# Out:
# Epoch 1/100
# 41/41 [==============================] - 1s 7ms/step - loss: 0.6310 - accuracy: 0.0000e+00 - val_loss: 0.5095 - val_accuracy: 0.0050
# Epoch 2/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.3460 - accuracy: 0.0175 - val_loss: 0.2110 - val_accuracy: 0.0299
# Epoch 3/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1819 - accuracy: 0.0524 - val_loss: 0.1593 - val_accuracy: 0.0299
# Epoch 4/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1618 - accuracy: 0.0399 - val_loss: 0.1536 - val_accuracy: 0.0299
# Epoch 5/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1573 - accuracy: 0.0461 - val_loss: 0.1520 - val_accuracy: 0.0547
# Epoch 6/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1547 - accuracy: 0.1297 - val_loss: 0.1512 - val_accuracy: 0.0547
# Epoch 7/100
# 41/41 [==============================] - 0s 5ms/step - loss: 0.1527 - accuracy: 0.0524 - val_loss: 0.1502 - val_accuracy: 0.0547
# Epoch 8/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1506 - accuracy: 0.0885 - val_loss: 0.1493 - val_accuracy: 0.0697
# Epoch 9/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1487 - accuracy: 0.0773 - val_loss: 0.1482 - val_accuracy: 0.1095
# Epoch 10/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1468 - accuracy: 0.1434 - val_loss: 0.1472 - val_accuracy: 0.0697
# Epoch 11/100
# 41/41 [==============================] - 0s 5ms/step - loss: 0.1449 - accuracy: 0.1347 - val_loss: 0.1464 - val_accuracy: 0.0597
# Epoch 12/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1430 - accuracy: 0.0885 - val_loss: 0.1455 - val_accuracy: 0.0746
# Epoch 13/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1411 - accuracy: 0.1322 - val_loss: 0.1447 - val_accuracy: 0.0796
# Epoch 14/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1394 - accuracy: 0.1072 - val_loss: 0.1438 - val_accuracy: 0.1294
# Epoch 15/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1376 - accuracy: 0.1571 - val_loss: 0.1431 - val_accuracy: 0.0746
# Epoch 16/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1359 - accuracy: 0.1272 - val_loss: 0.1420 - val_accuracy: 0.0796
# Epoch 17/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1342 - accuracy: 0.1421 - val_loss: 0.1414 - val_accuracy: 0.0796
# Epoch 18/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1326 - accuracy: 0.1372 - val_loss: 0.1406 - val_accuracy: 0.0796
# Epoch 19/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1311 - accuracy: 0.1347 - val_loss: 0.1398 - val_accuracy: 0.0846
# Epoch 20/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1295 - accuracy: 0.1347 - val_loss: 0.1390 - val_accuracy: 0.0945
# Epoch 21/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1279 - accuracy: 0.1434 - val_loss: 0.1382 - val_accuracy: 0.0995
# Epoch 22/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1264 - accuracy: 0.1521 - val_loss: 0.1373 - val_accuracy: 0.1045
# Epoch 23/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1250 - accuracy: 0.1621 - val_loss: 0.1364 - val_accuracy: 0.1095
# Epoch 24/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1235 - accuracy: 0.1484 - val_loss: 0.1355 - val_accuracy: 0.1144
# Epoch 25/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1221 - accuracy: 0.1708 - val_loss: 0.1347 - val_accuracy: 0.1095
# Epoch 26/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1206 - accuracy: 0.1559 - val_loss: 0.1338 - val_accuracy: 0.1144
# Epoch 27/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1192 - accuracy: 0.1546 - val_loss: 0.1329 - val_accuracy: 0.1144
# Epoch 28/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1177 - accuracy: 0.1746 - val_loss: 0.1321 - val_accuracy: 0.1144
# Epoch 29/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1163 - accuracy: 0.1671 - val_loss: 0.1312 - val_accuracy: 0.1045
# Epoch 30/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1150 - accuracy: 0.1633 - val_loss: 0.1302 - val_accuracy: 0.1045
# Epoch 31/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1136 - accuracy: 0.1683 - val_loss: 0.1290 - val_accuracy: 0.1144
# Epoch 32/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1123 - accuracy: 0.1845 - val_loss: 0.1283 - val_accuracy: 0.0945
# Epoch 33/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1109 - accuracy: 0.1721 - val_loss: 0.1273 - val_accuracy: 0.0995
# Epoch 34/100
# 41/41 [==============================] - 0s 5ms/step - loss: 0.1096 - accuracy: 0.1733 - val_loss: 0.1262 - val_accuracy: 0.0945
# Epoch 35/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1084 - accuracy: 0.1833 - val_loss: 0.1254 - val_accuracy: 0.1045
# Epoch 36/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1071 - accuracy: 0.1820 - val_loss: 0.1246 - val_accuracy: 0.0995
# Epoch 37/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1059 - accuracy: 0.1796 - val_loss: 0.1235 - val_accuracy: 0.0995
# Epoch 38/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1047 - accuracy: 0.1758 - val_loss: 0.1226 - val_accuracy: 0.0995
# Epoch 39/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1035 - accuracy: 0.1845 - val_loss: 0.1217 - val_accuracy: 0.0995
# Epoch 40/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1023 - accuracy: 0.1783 - val_loss: 0.1208 - val_accuracy: 0.1144
# Epoch 41/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1012 - accuracy: 0.1858 - val_loss: 0.1198 - val_accuracy: 0.1095
# Epoch 42/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.1001 - accuracy: 0.1883 - val_loss: 0.1191 - val_accuracy: 0.1144
# Epoch 43/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0990 - accuracy: 0.1883 - val_loss: 0.1180 - val_accuracy: 0.1144
# Epoch 44/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0979 - accuracy: 0.1883 - val_loss: 0.1174 - val_accuracy: 0.0995
# Epoch 45/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0968 - accuracy: 0.1970 - val_loss: 0.1164 - val_accuracy: 0.1144
# Epoch 46/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0958 - accuracy: 0.1945 - val_loss: 0.1157 - val_accuracy: 0.1045
# Epoch 47/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0948 - accuracy: 0.1820 - val_loss: 0.1149 - val_accuracy: 0.1045
# Epoch 48/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0938 - accuracy: 0.1858 - val_loss: 0.1139 - val_accuracy: 0.1144
# Epoch 49/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0929 - accuracy: 0.1983 - val_loss: 0.1133 - val_accuracy: 0.1045
# Epoch 50/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0919 - accuracy: 0.1833 - val_loss: 0.1126 - val_accuracy: 0.0995
# Epoch 51/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0910 - accuracy: 0.1845 - val_loss: 0.1117 - val_accuracy: 0.1045
# Epoch 52/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0901 - accuracy: 0.1920 - val_loss: 0.1110 - val_accuracy: 0.1144
# Epoch 53/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0893 - accuracy: 0.2020 - val_loss: 0.1102 - val_accuracy: 0.1144
# Epoch 54/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0884 - accuracy: 0.1895 - val_loss: 0.1096 - val_accuracy: 0.1144
# Epoch 55/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0876 - accuracy: 0.1820 - val_loss: 0.1089 - val_accuracy: 0.1095
# Epoch 56/100
# 41/41 [==============================] - 0s 5ms/step - loss: 0.0868 - accuracy: 0.1933 - val_loss: 0.1083 - val_accuracy: 0.1144
# Epoch 57/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0861 - accuracy: 0.1845 - val_loss: 0.1076 - val_accuracy: 0.1144
# Epoch 58/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0853 - accuracy: 0.1920 - val_loss: 0.1070 - val_accuracy: 0.1095
# Epoch 59/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0846 - accuracy: 0.1970 - val_loss: 0.1066 - val_accuracy: 0.1194
# Epoch 60/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0839 - accuracy: 0.2032 - val_loss: 0.1060 - val_accuracy: 0.1294
# Epoch 61/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0832 - accuracy: 0.2057 - val_loss: 0.1055 - val_accuracy: 0.1294
# Epoch 62/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0826 - accuracy: 0.2057 - val_loss: 0.1050 - val_accuracy: 0.1194
# Epoch 63/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0820 - accuracy: 0.2132 - val_loss: 0.1044 - val_accuracy: 0.1294
# Epoch 64/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0814 - accuracy: 0.1945 - val_loss: 0.1041 - val_accuracy: 0.1194
# Epoch 65/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0808 - accuracy: 0.2095 - val_loss: 0.1036 - val_accuracy: 0.1194
# Epoch 66/100
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0802 - accuracy: 0.1833 - val_loss: 0.1033 - val_accuracy: 0.1144
# Epoch 67/100
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0797 - accuracy: 0.1908 - val_loss: 0.1028 - val_accuracy: 0.1144
# Epoch 68/100
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0791 - accuracy: 0.1995 - val_loss: 0.1022 - val_accuracy: 0.1194
# Epoch 69/100
# 41/41 [==============================] - 0s 5ms/step - loss: 0.0786 - accuracy: 0.1995 - val_loss: 0.1018 - val_accuracy: 0.1194
# Epoch 70/100
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0781 - accuracy: 0.1958 - val_loss: 0.1015 - val_accuracy: 0.1194
# Epoch 71/100
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0777 - accuracy: 0.1983 - val_loss: 0.1011 - val_accuracy: 0.1144
# Epoch 72/100
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0772 - accuracy: 0.1858 - val_loss: 0.1007 - val_accuracy: 0.1144
# Epoch 73/100
# 41/41 [==============================] - 0s 7ms/step - loss: 0.0768 - accuracy: 0.2020 - val_loss: 0.1005 - val_accuracy: 0.1194
# Epoch 74/100
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0763 - accuracy: 0.1945 - val_loss: 0.1001 - val_accuracy: 0.1144
# Epoch 75/100
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0759 - accuracy: 0.1970 - val_loss: 0.0997 - val_accuracy: 0.1095
# Epoch 76/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0755 - accuracy: 0.1870 - val_loss: 0.0994 - val_accuracy: 0.1095
# Epoch 77/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0751 - accuracy: 0.2070 - val_loss: 0.0993 - val_accuracy: 0.1095
# Epoch 78/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0748 - accuracy: 0.2045 - val_loss: 0.0989 - val_accuracy: 0.1095
# Epoch 79/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0744 - accuracy: 0.2082 - val_loss: 0.0988 - val_accuracy: 0.1095
# Epoch 80/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0741 - accuracy: 0.2020 - val_loss: 0.0983 - val_accuracy: 0.1095
# Epoch 81/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0738 - accuracy: 0.2032 - val_loss: 0.0983 - val_accuracy: 0.1095
# Epoch 82/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0734 - accuracy: 0.2032 - val_loss: 0.0981 - val_accuracy: 0.1144
# Epoch 83/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0731 - accuracy: 0.2082 - val_loss: 0.0978 - val_accuracy: 0.1095
# Epoch 84/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0728 - accuracy: 0.2120 - val_loss: 0.0976 - val_accuracy: 0.1095
# Epoch 85/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0725 - accuracy: 0.1995 - val_loss: 0.0974 - val_accuracy: 0.1144
# Epoch 86/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0723 - accuracy: 0.2095 - val_loss: 0.0972 - val_accuracy: 0.1194
# Epoch 87/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0720 - accuracy: 0.1983 - val_loss: 0.0970 - val_accuracy: 0.1144
# Epoch 88/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0718 - accuracy: 0.2020 - val_loss: 0.0969 - val_accuracy: 0.1194
# Epoch 89/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0715 - accuracy: 0.1933 - val_loss: 0.0966 - val_accuracy: 0.1144
# Epoch 90/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0713 - accuracy: 0.1858 - val_loss: 0.0966 - val_accuracy: 0.1194
# Epoch 91/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0711 - accuracy: 0.2007 - val_loss: 0.0963 - val_accuracy: 0.1095
# Epoch 92/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0708 - accuracy: 0.2070 - val_loss: 0.0963 - val_accuracy: 0.1194
# Epoch 93/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0706 - accuracy: 0.2032 - val_loss: 0.0961 - val_accuracy: 0.1294
# Epoch 94/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0704 - accuracy: 0.2032 - val_loss: 0.0961 - val_accuracy: 0.1244
# Epoch 95/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0702 - accuracy: 0.2020 - val_loss: 0.0959 - val_accuracy: 0.1294
# Epoch 96/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0700 - accuracy: 0.2032 - val_loss: 0.0957 - val_accuracy: 0.1343
# Epoch 97/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0699 - accuracy: 0.1970 - val_loss: 0.0957 - val_accuracy: 0.1294
# Epoch 98/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0697 - accuracy: 0.1945 - val_loss: 0.0957 - val_accuracy: 0.1343
# Epoch 99/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0695 - accuracy: 0.2007 - val_loss: 0.0956 - val_accuracy: 0.1294
# Epoch 100/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0694 - accuracy: 0.2045 - val_loss: 0.0956 - val_accuracy: 0.1294

# %%
# Encode and decode some digits
# Note that we take them from the *test* set
encoded_imgs = encoder.predict(x_all)
decoded_imgs = decoder.predict(encoded_imgs)
# Out:
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step

# %%
import matplotlib.pyplot as plt

n = 10  # How many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_all[i].reshape(12, -1))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(12, -1))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
keras.utils.plot_model(autoencoder, show_shapes=True)

# %%
print(decoded_imgs[0].max())
print(decoded_imgs[0].min())
# Out:
# 0.98272616
# 0.00011516991

# %%
c_model.evaluate(x_all, y_all)
# Out:
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6386 - accuracy: 0.8504
# [0.638617217540741, 0.8504486680030823]

# %%
c_model.evaluate(decoded_imgs, y_all)
# Out:
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9477 - accuracy: 0.6859
# [0.9477073550224304, 0.6859421730041504]

# %%
# 10. 학습 시각화하기
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc = 'upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc = 'upper left')
plt.show()
